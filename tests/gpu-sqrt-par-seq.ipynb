# %%
import sys
sys.path.append('..//')

import jax
import numpy as np
import jax.numpy as jnp
from functools import partial
import matplotlib.pyplot as plt
from jax import jit, devices, make_jaxpr
import time
from tqdm import tqdm

jax.config.update("jax_enable_x64", True)

from parsmooth._base import MVNStandard, FunctionalModel, MVNSqrt
from parsmooth.linearization import cubature, extended, gauss_hermite
from parsmooth.methods import iterated_smoothing, smoothing, filtering
from bearings.bearings_utils import make_parameters
from bearings.bearing_data import get_data

# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()


warnings.filterwarnings("ignore")

# %%
device = jax.device_get("/GPU:1")

# %%
device = jax.devices("gpu")[1]

# %%
s1 = jnp.array([-1.5, 0.5])  # First sensor location
s2 = jnp.array([1., 1.])  # Second sensor location
r = 0.5  # Observation noise (stddev)
x0 = jnp.array([0.1, 0.2, 1, 0])  # initial true location
dt = 0.01  # discretization time step
qc = 0.01  # discretization noise
qw = 0.1  # discretization noise

T = 1000
_, true_states, ys = get_data(x0, dt, r, T, s1, s2)
Q, R, observation_function, transition_function = make_parameters(qc, qw, r, dt, s1, s2)

chol_Q = jnp.linalg.cholesky(Q)
chol_R = jnp.linalg.cholesky(R)

m0 = jnp.array([-4., -1., 2., 7., 3.])
chol_P0 = jnp.eye(5)
P0 = jnp.eye(5)

init = MVNStandard(m0, P0)
chol_init = MVNSqrt(m0, chol_P0)

initial_states =  MVNStandard(jnp.repeat(jnp.array([[-1., -1., 6., 4., 2.]]),T + 1, axis=0),
                                                     jnp.repeat(jnp.eye(5).reshape(1, 5, 5), T + 1, axis=0))
initial_states_sqrt = MVNSqrt(jnp.repeat(jnp.array([[-1., -1., 6., 4., 2.]]),T + 1, axis=0),
                              jnp.repeat(jnp.eye(5).reshape(1, 5, 5), T + 1, axis=0))


sqrt_transition_model = FunctionalModel(transition_function, MVNSqrt(jnp.zeros((5,)), chol_Q))
transition_model = FunctionalModel(transition_function, MVNStandard(jnp.zeros((5,)), Q))

sqrt_observation_model = FunctionalModel(observation_function, MVNSqrt(jnp.zeros((2,)), chol_R))
observation_model = FunctionalModel(observation_function, MVNStandard(jnp.zeros((2,)), R))
# Out:
# 2021-11-15 15:46:18.478592: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:18.526277: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:18.573297: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:18.620296: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:18.673164: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:18.723374: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:19.451105: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:19.452083: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:20.772962: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:20.776935: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:20.838631: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:20.892358: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:20.937902: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:20.980572: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:21.030183: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:21.112449: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:21.201153: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:21.272656: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:21.322476: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.

# %%
def cubature_sqrt_seq(y, initial_points_sqrt, iteration):
    sqrt_seq_res = iterated_smoothing(y, chol_init, sqrt_transition_model, sqrt_observation_model,
                                      cubature, initial_points_sqrt, False,
                                      criterion=lambda i, *_: i < iteration)
    return sqrt_seq_res

# %%
def cubature_sqrt_par(y, initial_points_sqrt, iteration):
    sqrt_par_res = iterated_smoothing(y, chol_init, sqrt_transition_model, sqrt_observation_model,
                                      cubature, initial_points_sqrt, True,
                                      criterion=lambda i, *_: i < iteration)
    return sqrt_par_res

# %%
def func(method, lengths, n_runs=1, n_iter=10, sqrt=False):
    res_mean = []
    for j in tqdm(lengths):
        observations_slice = ys[:j]
        
        if sqrt:
            init_linearizations_points_slice = initial_states_sqrt.mean[:j+1]
            init_linearizations_chols_slice = initial_states_sqrt.chol[:j+1]
            init_linearizations_states = MVNSqrt(init_linearizations_points_slice, init_linearizations_chols_slice)
            args = observations_slice, init_linearizations_states, n_iter
        else:
            init_linearizations_points_slice = initial_states.mean[:j+1]
            init_linearizations_covs_slice = initial_states.cov[:j+1]
            init_linearizations_states = MVNStandard(init_linearizations_points_slice, init_linearizations_covs_slice)
            args = observations_slice, init_linearizations_states, n_iter
            
        s = method(*args)                
        s.mean.block_until_ready()
        run_times = []
        for _ in range(n_runs):
            tic = time.time()
            s_states = method(*args)
            s_states.mean.block_until_ready()
            toc = time.time()
            run_times.append(toc - tic)
        res_mean.append(np.mean(run_times))
    return np.array(res_mean)

# %%
lengths_space = np.logspace(1, np.log10(T), num=20).astype(np.int32)

# %%
gpu_cubature_sqrt_par = jit(cubature_sqrt_par, device=device)
gpu_cubature_sqrt_seq = jit(cubature_sqrt_seq, device=device)

# %%
warnings.filterwarnings("ignore")

gpu_cubature_sqrt_par_time = func(gpu_cubature_sqrt_par, lengths_space, sqrt=True)
# Out:
#   0%|                                                    | 0/20 [00:00<?, ?it/s]2021-11-15 15:46:21.481126: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:21.546951: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:25.429934: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:25.472715: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.877406: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.877868: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.879655: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.887670: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.890883: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.897009: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.903369: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.907161: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.910304: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.914690: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.914893: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.916730: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.917042: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.925441: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.927355: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.928065: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.930108: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.930591: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.933259: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.936300: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.937700: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.937755: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.937825: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.937933: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.938005: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.939034: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.941290: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.941684: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.942690: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.943264: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.943377: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.943572: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.944120: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.944280: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.944490: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.949363: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.955470: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.955922: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.959402: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.961089: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.961324: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.962014: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.962197: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.963017: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.964701: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.966358: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.968032: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.971618: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.972417: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.973410: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.974012: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.974410: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.977077: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.977749: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.978285: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.979565: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.979718: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.980179: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.980751: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.981567: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.982959: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.985775: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.985967: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.988446: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.989890: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.990260: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.990441: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.990512: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.990707: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.990779: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.991643: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.992834: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.994382: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.994525: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.997703: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:27.998228: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.002232: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.002393: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.002435: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.003610: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.003632: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.003826: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.004328: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.004493: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.005446: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.005713: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.007158: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.008130: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.009009: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.010903: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.012465: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.018205: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.022769: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.035204: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.180388: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:28.248704: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
#   5%|██▏                                         | 1/20 [00:08<02:49,  8.91s/it]2021-11-15 15:46:30.382100: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:30.455985: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.564238: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.572170: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.572333: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.572837: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.573540: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.573650: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.575549: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.575619: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.575985: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.576050: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.576663: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.578106: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.578176: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.578552: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.578680: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.580002: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.580260: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.580543: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.580962: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.581427: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.582059: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.582467: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.582990: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:46:34.583013: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# ...
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.258137: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.258587: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.258929: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.259040: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.260115: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.260536: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.261023: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.261399: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.261632: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.264895: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.265026: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.265497: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.265600: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.266411: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.266605: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.268402: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.274167: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.274394: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.275578: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.275830: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.276713: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.277439: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.286971: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.287195: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.289911: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.290143: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.291319: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.296218: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.299970: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.300402: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.302707: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.309649: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.325128: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.330584: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.332376: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.347876: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.356168: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.359298: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.361848: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.410009: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:49:47.415695: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 100%|███████████████████████████████████████████| 20/20 [03:40<00:00, 11.00s/it]

# %%
warnings.filterwarnings("ignore")
gpu_cubature_sqrt_seq_time = func(gpu_cubature_sqrt_seq, lengths_space, sqrt = True)
# Out:
#   0%|                                                    | 0/20 [00:00<?, ?it/s]2021-11-15 15:50:04.193346: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.200411: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.200711: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.200928: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.201222: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.201469: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.202947: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.203595: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.203646: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.203684: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.203728: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.203769: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.203991: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.204289: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.204347: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.204755: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.206789: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.207341: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.207520: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.207905: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.208436: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.209921: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.209967: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.210221: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.210264: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.210455: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.210526: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.210593: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.210923: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.210971: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.211090: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.211139: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.211712: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.211831: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.211859: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.211901: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.212088: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.212120: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.212142: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.212440: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.212559: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.212766: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.212942: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.213001: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.213303: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.213536: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.214057: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.214116: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.214354: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.214573: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.214612: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.214660: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.214685: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.214838: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.215225: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.215349: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.215389: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.215677: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.215773: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.215816: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.216064: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.216113: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.216613: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.217184: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.217822: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.218118: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.218333: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.218353: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.218776: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.218874: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.219059: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.219257: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.219327: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.219679: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.220539: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.221872: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.221997: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.222018: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.223781: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.225644: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.228846: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.235102: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.235408: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.245321: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.246766: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.246998: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.248902: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.256512: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.259885: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.265092: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.266592: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.270487: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.277029: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.284759: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.288089: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:04.307133: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
#   5%|██▏                                         | 1/20 [00:03<01:07,  3.53s/it]2021-11-15 15:50:07.060520: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.060706: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.060822: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.062091: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.062889: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.063302: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.064114: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.064151: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.064194: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.064318: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.064370: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.064418: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.064655: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.064785: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.065191: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.065441: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.066000: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.066119: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.066191: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.066625: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.066675: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.066728: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.066822: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.066927: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.067038: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.067433: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.068217: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.068377: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.068458: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:50:07.068507: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# ...
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.392083: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.392115: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.392221: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.392241: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.392626: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.393171: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.393560: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.395164: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.395394: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.399329: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.399771: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.399955: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.400282: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.405136: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.405329: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.406255: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.408665: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.415243: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.417172: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.427670: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.429702: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.432388: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.432861: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.433414: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.434228: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.435204: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.435899: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.437074: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.437531: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.439608: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.440532: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.442222: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.442629: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.442826: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.447566: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.448508: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.449435: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.453123: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.456203: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.462009: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-15 15:54:03.468500: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 100%|███████████████████████████████████████████| 20/20 [04:55<00:00, 14.77s/it]

# %%
# jnp.savez("GPU-cubature-sqrt-T10e4-time",
#           gpu_cubature_sqrt_par_time=gpu_cubature_sqrt_par_time,
#           gpu_cubature_sqrt_seq_time=gpu_cubature_sqrt_seq_time)

# %%
plt.figure(figsize=(10,7))
plt.loglog(lengths_space, gpu_cubature_sqrt_par_time, label="cubature-sqrt-Par-GPU", linestyle="-.", linewidth=3)
plt.loglog(lengths_space, gpu_cubature_sqrt_seq_time, label="cubature-sqrt-Seq-GPU", linestyle="-.", linewidth=3)

plt.grid(True, which="both")
plt.title("cubature-GPU, sequential v.s parallel")
plt.legend()
plt.show()

# %%
filtering_res = filtering(ys, chol_init, sqrt_transition_model, sqrt_observation_model, cubature, initial_states_sqrt, True)

# %%
spec_filtering = lambda : filtering(ys, chol_init, sqrt_transition_model, sqrt_observation_model, cubature, initial_states_sqrt, True)

# %%
filtering_jaxpr = jax.make_jaxpr(spec_filtering)()

# %%
filtering_jaxpr
# Out:
# { lambda a:f64[1001,5] b:f64[1001,5,5] c:f64[5] d:f64[5,5] e:f64[5,10] f:i64[5] g:f64[10]
#     h:f64[1,10] i:f64[10,1] j:f64[5,5] k:f64[5] l:f64[5,10] m:f64[2] n:f64[2] o:f64[10]
#     p:f64[1,10] q:f64[10,1] r:f64[2,2] s:f64[2] t:f32[1000,2]; . let
#     u:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     v:f64[1000,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1), collapsed_slice_dims=(), start_index_map=(0,))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1000, 5)
#       unique_indices=True
#     ] a u
#     w:f64[1000,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1)
#       shape=(1000, 5)
#     ] v
#     x:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     y:f64[1000,5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(0,))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1000, 5, 5)
#       unique_indices=True
#     ] b x
#     z:f64[1000,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(1000, 5, 5)
#     ] y
#     ba:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 1
#     bb:f64[1000,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1), collapsed_slice_dims=(), start_index_map=(0,))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1000, 5)
#       unique_indices=True
#     ] a ba
#     bc:f64[1000,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1)
#       shape=(1000, 5)
#     ] bb
#     bd:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 1
#     be:f64[1000,5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(0,))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1000, 5, 5)
#       unique_indices=True
#     ] b bd
#     bf:f64[1000,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(1000, 5, 5)
#     ] be
#     bg:f64[1,5] = broadcast_in_dim[broadcast_dimensions=(1,) shape=(1, 5)] c
#     bh:f64[999,5] = broadcast_in_dim[broadcast_dimensions=() shape=(999, 5)] 0.0
#     bi:f64[1000,5] = concatenate[dimension=0] bg bh
#     bj:f64[1,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(1, 5, 5)
#     ] d
#     bk:f64[999,5,5] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(999, 5, 5)
#     ] 0.0
#     bl:f64[1000,5,5] = concatenate[dimension=0] bj bk
#     bm:f64[1000,1,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 2)
#       shape=(1000, 1, 5)
#     ] w
#     bn:f64[1000,5,10] = dot_general[
#       dimension_numbers=(((2,), (0,)), ((), ()))
#       precision=None
#       preferred_element_type=None
#     ] z e
#     bo:f64[1000,10,5] = transpose[permutation=(0, 2, 1)] bn
#     bp:f64[1000,10,5] = add bm bo
#     bq:f64[1000,10,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; br:i64[5] bs:f64[1000,10,5]. let
#           bt:bool[] = lt -1 0
#           bu:i64[] = add -1 5
#           bv:i64[] = select bt bu -1
#           bw:i32[] = convert_element_type[new_dtype=int32 weak_type=False] bv
#           bx:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] bw
#           by:f64[1000,10] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1), collapsed_slice_dims=(2,), start_index_map=(2,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1000, 10, 1)
#             unique_indices=True
#           ] bs bx
#           bz:f64[1000,10] = abs by
#           ca:bool[1000,10] = lt bz 1e-06
#           cb:f64[1000,10] = mul by 0.01
#           cc:f64[1000,10] = cos cb
#           cd:f64[1000,10] = mul by 0.01
#           ce:f64[1000,10] = sin cd
#           cf:i32[1000,10] = convert_element_type[
#             new_dtype=int32
#             weak_type=False
#           ] ca
#           cg:bool[1000,10] = eq cf 0
#           ch:f64[1000,10] = stop_gradient cc
#           _:f64[1000,10] = select cg cc ch
#           ci:bool[1000,10] = eq cf 0
#           cj:f64[1000,10] = stop_gradient ce
#           _:f64[1000,10] = select ci ce cj
#           ck:bool[1000,10] = eq cf 0
#           cl:f64[1000,10] = stop_gradient cc
#           cm:f64[1000,10] = select ck cc cl
#           cn:bool[1000,10] = eq cf 0
#           co:f64[1000,10] = stop_gradient by
#           cp:f64[1000,10] = select cn by co
#           cq:bool[1000,10] = eq cf 0
#           cr:f64[1000,10] = stop_gradient ce
#           cs:f64[1000,10] = select cq ce cr
#           ct:f64[1000,10] = sub cm 1.0
#           cu:f64[1000,10] = div ct cp
#           cv:f64[1000,10] = div cs cp
#           cw:bool[1000,10] = eq cf 1
#           cx:f64[1000,10] = stop_gradient cc
#           cy:f64[1000,10] = select cw cc cx
#           cz:bool[1000,10] = eq cf 1
#           da:f64[1000,10] = stop_gradient ce
#           db:f64[1000,10] = select cz ce da
#           dc:bool[1000,10] = eq cf 1
#           dd:f64[1000,10] = stop_gradient cc
#           _:f64[1000,10] = select dc cc dd
#           de:bool[1000,10] = eq cf 1
#           df:f64[1000,10] = stop_gradient by
#           _:f64[1000,10] = select de by df
#           dg:bool[1000,10] = eq cf 1
#           dh:f64[1000,10] = stop_gradient ce
#           _:f64[1000,10] = select dg ce dh
#           di:f64[10] = broadcast_in_dim[broadcast_dimensions=() shape=(10,)] 0.0
#           dj:f64[10] = broadcast_in_dim[broadcast_dimensions=() shape=(10,)] 0.01
#           dk:bool[1000,10] = lt cf 1
#           _:i32[1000,10] = sub cf 1
#           dl:f64[1000,10] = select dk cm cy
#           dm:bool[1000,10] = lt cf 1
#           _:i32[1000,10] = sub cf 1
#           dn:f64[1000,10] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(1000, 10)
#           ] di
#           do:f64[1000,10] = select dm cu dn
#           dp:bool[1000,10] = lt cf 1
#           _:i32[1000,10] = sub cf 1
#           dq:f64[1000,10] = select dp cs db
#           dr:bool[1000,10] = lt cf 1
#           _:i32[1000,10] = sub cf 1
#           ds:f64[1000,10] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(1000, 10)
#           ] dj
#           dt:f64[1000,10] = select dr cv ds
#           du:f64[1000,10] = neg do
#           dv:f64[1000,10] = neg dq
#           dw:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 1
#           dx:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           dy:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] dt
#           dz:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] du
#           ea:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           eb:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] dw
#           ec:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] dx
#           ed:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] ea
#           ee:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] eb
#           ef:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] ec
#           eg:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] ed
#           eh:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] ee
#           ei:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] ef
#           ej:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] eg
#           ek:f64[1000,10,5] = concatenate[dimension=2] eh ei dy dz ej
#           el:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           em:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 1
#           en:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] do
#           eo:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] dt
#           ep:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           eq:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] el
#           er:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] em
#           es:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] ep
#           et:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] eq
#           eu:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] er
#           ev:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] es
#           ew:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] et
#           ex:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] eu
#           ey:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] ev
#           ez:f64[1000,10,5] = concatenate[dimension=2] ew ex en eo ey
#           fa:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           fb:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           fc:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] dl
#           fd:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] dq
#           fe:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           ff:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] fa
#           fg:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] fb
#           fh:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] fe
#           fi:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] ff
#           fj:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] fg
#           fk:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] fh
#           fl:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] fi
#           fm:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] fj
#           fn:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] fk
#           fo:f64[1000,10,5] = concatenate[dimension=2] fl fm fc fd fn
#           fp:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           fq:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           fr:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] dv
#           fs:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] dl
#           ft:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           fu:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] fp
#           fv:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] fq
#           fw:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] ft
#           fx:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] fu
#           fy:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] fv
#           fz:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] fw
#           ga:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] fx
#           gb:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] fy
#           gc:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] fz
#           gd:f64[1000,10,5] = concatenate[dimension=2] ga gb fr fs gc
#           ge:f64[1000,10,1,5] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 3)
#             shape=(1000, 10, 1, 5)
#           ] ek
#           gf:f64[1000,10,1,5] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 3)
#             shape=(1000, 10, 1, 5)
#           ] ez
#           gg:f64[1000,10,1,5] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 3)
#             shape=(1000, 10, 1, 5)
#           ] fo
#           gh:f64[1000,10,1,5] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 3)
#             shape=(1000, 10, 1, 5)
#           ] gd
#           gi:i64[1,5] = broadcast_in_dim[broadcast_dimensions=(1,) shape=(1, 5)] br
#           gj:f64[1,5] = convert_element_type[new_dtype=float64 weak_type=False] gi
#           gk:f64[10,1,5] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(10, 1, 5)
#           ] gj
#           gl:f64[1000,10,1,5] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2, 3)
#             shape=(1000, 10, 1, 5)
#           ] gk
#           gm:f64[1000,10,5,5] = concatenate[dimension=2] ge gf gg gh gl
#           gn:f64[1000,10,5] = dot_general[
#             dimension_numbers=(((3,), (2,)), ((0, 1), (0, 1)))
#             precision=None
#             preferred_element_type=None
#           ] gm bs
#         in (gn,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(vmap(<unnamed wrapped function>))
#     ] f bp
#     go:f64[1000,5] = dot_general[
#       dimension_numbers=(((0,), (1,)), ((), ()))
#       precision=None
#       preferred_element_type=None
#     ] g bq
#     gp:f64[1000,1,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 2)
#       shape=(1000, 1, 5)
#     ] w
#     gq:f64[1000,10,5] = sub bp gp
#     gr:f64[1000,5,10] = transpose[permutation=(0, 2, 1)] gq
#     gs:f64[1000,1,10] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(1000, 1, 10)
#     ] h
#     gt:f64[1000,5,10] = mul gr gs
#     gu:f64[1000,1,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 2)
#       shape=(1000, 1, 5)
#     ] go
#     gv:f64[1000,10,5] = sub bq gu
#     gw:f64[1000,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] gt gv
#     gx:f64[1000,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; gy:f64[1000,5,5] gz:f64[1000,5,5]. let
#           ha:f64[1000,5,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=False
#             unit_diagonal=False
#           ] gy gz
#           hb:f64[1000,5,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=True
#             unit_diagonal=False
#           ] gy ha
#         in (hb,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(_cho_solve)
#     ] z gw
#     hc:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] gx
#     hd:f64[10,1] = sqrt i
#     he:f64[1000,1,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 2)
#       shape=(1000, 1, 5)
#     ] go
#     hf:f64[1000,10,5] = sub bq he
#     hg:f64[1000,10,1] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(1000, 10, 1)
#     ] hd
#     hh:f64[1000,10,5] = mul hg hf
#     hi:f64[1000,5,10] = transpose[permutation=(0, 2, 1)] hh
#     hj:f64[1000,10,5] = transpose[permutation=(0, 2, 1)] hi
#     _:f64[1000,10,5] hk:f64[1000,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; hl:f64[1000,10,5]. let
#           hm:f64[1000,10,5] hn:f64[1000,5,5] = qr[full_matrices=False] hl
#         in (hm, hn) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] hj
#     ho:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] hk
#     hp:f64[1000,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(1000, 5, 5)
#     ] j
#     hq:f64[1000,5,10] = concatenate[dimension=2] ho hp
#     hr:f64[1000,10,5] = transpose[permutation=(0, 2, 1)] hq
#     _:f64[1000,10,5] hs:f64[1000,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; ht:f64[1000,10,5]. let
#           hu:f64[1000,10,5] hv:f64[1000,5,5] = qr[full_matrices=False] ht
#         in (hu, hv) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] hr
#     hw:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] hs
#     hx:f64[1000,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] hc z
#     hy:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] hw
#     hz:f64[1000,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] hw hy
#     ia:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] hx
#     ib:f64[1000,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] hx ia
#     ic:f64[1000,5,5] = sub hz ib
#     id:f64[1000,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; ie:f64[1000,5,5]. let
#           if:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] ie
#           ig:f64[1000,5,5] = add ie if
#           ih:f64[1000,5,5] = div ig 2.0
#           ii:f64[1000,5,5] = cholesky ih
#           ij:f64[1000,5,5] = xla_call[
#             backend=None
#             call_jaxpr={ lambda ; ik:f64[1000,5,5]. let
#                 il:i32[5,5] = iota[dimension=0 dtype=int32 shape=(5, 5)]
#                 im:i32[5,5] = add il 0
#                 in:i32[5,5] = iota[dimension=1 dtype=int32 shape=(5, 5)]
#                 io:bool[5,5] = ge im in
#                 ip:bool[5,5] = convert_element_type[
#                   new_dtype=bool
#                   weak_type=False
#                 ] io
#                 iq:bool[1000,5,5] = broadcast_in_dim[
#                   broadcast_dimensions=(1, 2)
#                   shape=(1000, 5, 5)
#                 ] ip
#                 ir:f64[1000,5,5] = broadcast_in_dim[
#                   broadcast_dimensions=()
#                   shape=(1000, 5, 5)
#                 ] 0.0
#                 is:f64[1000,5,5] = select iq ik ir
#               in (is,) }
#             device=None
#             donated_invars=(False,)
#             inline=False
#             name=tril
#           ] ii
#           it:f64[1000,5,5] = xla_call[
#             backend=None
#             call_jaxpr={ lambda ; iu:f64[1000,5,5]. let
#                 iv:i32[5,5] = iota[dimension=0 dtype=int32 shape=(5, 5)]
#                 iw:i32[5,5] = add iv 0
#                 ix:i32[5,5] = iota[dimension=1 dtype=int32 shape=(5, 5)]
#                 iy:bool[5,5] = ge iw ix
#                 iz:bool[5,5] = convert_element_type[
#                   new_dtype=bool
#                   weak_type=False
#                 ] iy
#                 ja:bool[5,5] = broadcast_in_dim[
#                   broadcast_dimensions=(0, 1)
#                   shape=(5, 5)
#                 ] iz
#                 jb:f64[5,5] = broadcast_in_dim[
#                   broadcast_dimensions=()
#                   shape=(5, 5)
#                 ] 0.0
#                 jc:bool[1000,5,5] = broadcast_in_dim[
#                   broadcast_dimensions=(1, 2)
#                   shape=(1000, 5, 5)
#                 ] ja
#                 jd:f64[1000,5,5] = broadcast_in_dim[
#                   broadcast_dimensions=(1, 2)
#                   shape=(1000, 5, 5)
#                 ] jb
#                 je:f64[1000,5,5] = select jc iu jd
#               in (je,) }
#             device=None
#             donated_invars=(False,)
#             inline=False
#             name=vmap(tril)
#           ] ij
#         in (it,) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_cholesky)
#     ] ic
#     jf:f64[1000,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] hc w
#     jg:f64[1000,5] = sub go jf
#     jh:f64[1000,5] = broadcast_in_dim[broadcast_dimensions=(1,) shape=(1000, 5)] k
#     ji:f64[1000,5] = add jg jh
#     jj:f64[1000,1,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 2)
#       shape=(1000, 1, 5)
#     ] bc
#     jk:f64[1000,5,10] = dot_general[
#       dimension_numbers=(((2,), (0,)), ((), ()))
#       precision=None
#       preferred_element_type=None
#     ] bf l
#     jl:f64[1000,10,5] = transpose[permutation=(0, 2, 1)] jk
#     jm:f64[1000,10,5] = add jj jl
#     jn:f64[1000,10,2] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; jo:f64[2] jp:f64[2] jq:f64[1000,10,5]. let
#           jr:bool[] = lt 1 0
#           js:i64[] = add 1 5
#           jt:i64[] = select jr js 1
#           ju:i32[] = convert_element_type[new_dtype=int32 weak_type=False] jt
#           jv:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] ju
#           jw:f64[1000,10] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1), collapsed_slice_dims=(2,), start_index_map=(2,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1000, 10, 1)
#             unique_indices=True
#           ] jq jv
#           jx:bool[] = lt 1 0
#           jy:i64[] = add 1 2
#           jz:i64[] = select jx jy 1
#           ka:i32[] = convert_element_type[new_dtype=int32 weak_type=False] jz
#           kb:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] ka
#           kc:f64[] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(), collapsed_slice_dims=(0,), start_index_map=(0,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1,)
#             unique_indices=True
#           ] jo kb
#           kd:f64[1000,10] = sub jw kc
#           ke:bool[] = lt 0 0
#           kf:i64[] = add 0 5
#           kg:i64[] = select ke kf 0
#           kh:i32[] = convert_element_type[new_dtype=int32 weak_type=False] kg
#           ki:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] kh
#           kj:f64[1000,10] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1), collapsed_slice_dims=(2,), start_index_map=(2,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1000, 10, 1)
#             unique_indices=True
#           ] jq ki
#           kk:bool[] = lt 0 0
#           kl:i64[] = add 0 2
#           km:i64[] = select kk kl 0
#           kn:i32[] = convert_element_type[new_dtype=int32 weak_type=False] km
#           ko:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] kn
#           kp:f64[] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(), collapsed_slice_dims=(0,), start_index_map=(0,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1,)
#             unique_indices=True
#           ] jo ko
#           kq:f64[1000,10] = sub kj kp
#           kr:f64[1000,10] = atan2 kd kq
#           ks:bool[] = lt 1 0
#           kt:i64[] = add 1 5
#           ku:i64[] = select ks kt 1
#           kv:i32[] = convert_element_type[new_dtype=int32 weak_type=False] ku
#           kw:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] kv
#           kx:f64[1000,10] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1), collapsed_slice_dims=(2,), start_index_map=(2,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1000, 10, 1)
#             unique_indices=True
#           ] jq kw
#           ky:bool[] = lt 1 0
#           kz:i64[] = add 1 2
#           la:i64[] = select ky kz 1
#           lb:i32[] = convert_element_type[new_dtype=int32 weak_type=False] la
#           lc:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] lb
#           ld:f64[] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(), collapsed_slice_dims=(0,), start_index_map=(0,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1,)
#             unique_indices=True
#           ] jp lc
#           le:f64[1000,10] = sub kx ld
#           lf:bool[] = lt 0 0
#           lg:i64[] = add 0 5
#           lh:i64[] = select lf lg 0
#           li:i32[] = convert_element_type[new_dtype=int32 weak_type=False] lh
#           lj:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] li
#           lk:f64[1000,10] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1), collapsed_slice_dims=(2,), start_index_map=(2,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1000, 10, 1)
#             unique_indices=True
#           ] jq lj
#           ll:bool[] = lt 0 0
#           lm:i64[] = add 0 2
#           ln:i64[] = select ll lm 0
#           lo:i32[] = convert_element_type[new_dtype=int32 weak_type=False] ln
#           lp:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] lo
#           lq:f64[] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(), collapsed_slice_dims=(0,), start_index_map=(0,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1,)
#             unique_indices=True
#           ] jp lp
#           lr:f64[1000,10] = sub lk lq
#           ls:f64[1000,10] = atan2 le lr
#           lt:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] kr
#           lu:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] ls
#           lv:f64[1000,10,2] = concatenate[dimension=2] lt lu
#         in (lv,) }
#       device=None
#       donated_invars=(False, False, False)
#       inline=False
#       name=vmap(vmap(<unnamed wrapped function>))
#     ] m n jm
#     lw:f64[1000,2] = dot_general[
#       dimension_numbers=(((0,), (1,)), ((), ()))
#       precision=None
#       preferred_element_type=None
#     ] o jn
#     lx:f64[1000,1,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 2)
#       shape=(1000, 1, 5)
#     ] bc
#     ly:f64[1000,10,5] = sub jm lx
#     lz:f64[1000,5,10] = transpose[permutation=(0, 2, 1)] ly
#     ma:f64[1000,1,10] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(1000, 1, 10)
#     ] p
#     mb:f64[1000,5,10] = mul lz ma
#     mc:f64[1000,1,2] = broadcast_in_dim[
#       broadcast_dimensions=(0, 2)
#       shape=(1000, 1, 2)
#     ] lw
#     md:f64[1000,10,2] = sub jn mc
#     me:f64[1000,5,2] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] mb md
#     mf:f64[1000,5,2] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; mg:f64[1000,5,5] mh:f64[1000,5,2]. let
#           mi:f64[1000,5,2] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=False
#             unit_diagonal=False
#           ] mg mh
#           mj:f64[1000,5,2] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=True
#             unit_diagonal=False
#           ] mg mi
#         in (mj,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(_cho_solve)
#     ] bf me
#     mk:f64[1000,2,5] = transpose[permutation=(0, 2, 1)] mf
#     ml:f64[10,1] = sqrt q
#     mm:f64[1000,1,2] = broadcast_in_dim[
#       broadcast_dimensions=(0, 2)
#       shape=(1000, 1, 2)
#     ] lw
#     mn:f64[1000,10,2] = sub jn mm
#     mo:f64[1000,10,1] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(1000, 10, 1)
#     ] ml
#     mp:f64[1000,10,2] = mul mo mn
#     mq:f64[1000,2,10] = transpose[permutation=(0, 2, 1)] mp
#     mr:f64[1000,10,2] = transpose[permutation=(0, 2, 1)] mq
#     _:f64[1000,10,2] ms:f64[1000,2,2] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; mt:f64[1000,10,2]. let
#           mu:f64[1000,10,2] mv:f64[1000,2,2] = qr[full_matrices=False] mt
#         in (mu, mv) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] mr
#     mw:f64[1000,2,2] = transpose[permutation=(0, 2, 1)] ms
#     mx:f64[1000,2,2] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(1000, 2, 2)
#     ] r
#     my:f64[1000,2,4] = concatenate[dimension=2] mw mx
#     mz:f64[1000,4,2] = transpose[permutation=(0, 2, 1)] my
#     _:f64[1000,4,2] na:f64[1000,2,2] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; nb:f64[1000,4,2]. let
#           nc:f64[1000,4,2] nd:f64[1000,2,2] = qr[full_matrices=False] nb
#         in (nc, nd) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] mz
#     ne:f64[1000,2,2] = transpose[permutation=(0, 2, 1)] na
#     nf:f64[1000,2,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] mk bf
#     ng:f64[1000,2,2] = transpose[permutation=(0, 2, 1)] ne
#     nh:f64[1000,2,2] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ne ng
#     ni:f64[1000,5,2] = transpose[permutation=(0, 2, 1)] nf
#     nj:f64[1000,2,2] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] nf ni
#     nk:f64[1000,2,2] = sub nh nj
#     nl:f64[1000,2,2] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; nm:f64[1000,2,2]. let
#           nn:f64[1000,2,2] = transpose[permutation=(0, 2, 1)] nm
#           no:f64[1000,2,2] = add nm nn
#           np:f64[1000,2,2] = div no 2.0
#           nq:f64[1000,2,2] = cholesky np
#           nr:f64[1000,2,2] = xla_call[
#             backend=None
#             call_jaxpr={ lambda ; ns:f64[1000,2,2]. let
#                 nt:i32[2,2] = iota[dimension=0 dtype=int32 shape=(2, 2)]
#                 nu:i32[2,2] = add nt 0
#                 nv:i32[2,2] = iota[dimension=1 dtype=int32 shape=(2, 2)]
#                 nw:bool[2,2] = ge nu nv
#                 nx:bool[2,2] = convert_element_type[
#                   new_dtype=bool
#                   weak_type=False
#                 ] nw
#                 ny:bool[1000,2,2] = broadcast_in_dim[
#                   broadcast_dimensions=(1, 2)
#                   shape=(1000, 2, 2)
#                 ] nx
#                 nz:f64[1000,2,2] = broadcast_in_dim[
#                   broadcast_dimensions=()
#                   shape=(1000, 2, 2)
#                 ] 0.0
#                 oa:f64[1000,2,2] = select ny ns nz
#               in (oa,) }
#             device=None
#             donated_invars=(False,)
#             inline=False
#             name=tril
#           ] nq
#           ob:f64[1000,2,2] = xla_call[
#             backend=None
#             call_jaxpr={ lambda ; oc:f64[1000,2,2]. let
#                 od:i32[2,2] = iota[dimension=0 dtype=int32 shape=(2, 2)]
#                 oe:i32[2,2] = add od 0
#                 of:i32[2,2] = iota[dimension=1 dtype=int32 shape=(2, 2)]
#                 og:bool[2,2] = ge oe of
#                 oh:bool[2,2] = convert_element_type[
#                   new_dtype=bool
#                   weak_type=False
#                 ] og
#                 oi:bool[2,2] = broadcast_in_dim[
#                   broadcast_dimensions=(0, 1)
#                   shape=(2, 2)
#                 ] oh
#                 oj:f64[2,2] = broadcast_in_dim[
#                   broadcast_dimensions=()
#                   shape=(2, 2)
#                 ] 0.0
#                 ok:bool[1000,2,2] = broadcast_in_dim[
#                   broadcast_dimensions=(1, 2)
#                   shape=(1000, 2, 2)
#                 ] oi
#                 ol:f64[1000,2,2] = broadcast_in_dim[
#                   broadcast_dimensions=(1, 2)
#                   shape=(1000, 2, 2)
#                 ] oj
#                 om:f64[1000,2,2] = select ok oc ol
#               in (om,) }
#             device=None
#             donated_invars=(False,)
#             inline=False
#             name=vmap(tril)
#           ] nr
#         in (ob,) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_cholesky)
#     ] nk
#     on:f64[1000,2] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] mk bc
#     oo:f64[1000,2] = sub lw on
#     op:f64[1000,2] = broadcast_in_dim[broadcast_dimensions=(1,) shape=(1000, 2)] s
#     oq:f64[1000,2] = add oo op
#     or:f64[1000,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] hc bi
#     os:f64[1000,5] = add or ji
#     ot:f64[1000,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] hc bl
#     ou:f64[1000,5,10] = concatenate[dimension=2] ot id
#     ov:f64[1000,10,5] = transpose[permutation=(0, 2, 1)] ou
#     _:f64[1000,10,5] ow:f64[1000,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; ox:f64[1000,10,5]. let
#           oy:f64[1000,10,5] oz:f64[1000,5,5] = qr[full_matrices=False] ox
#         in (oy, oz) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] ov
#     pa:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] ow
#     pb:f64[1000,2,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] mk pa
#     pc:f64[5,2] = broadcast_in_dim[broadcast_dimensions=() shape=(5, 2)] 0.0
#     pd:f64[1000,7,7] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; pe:f64[1000,2,5] pf:f64[1000,2,2] pg:f64[1000,5,5] ph:f64[5,2]. let
#           pi:f64[1000,2,7] = concatenate[dimension=2] pe pf
#           pj:f64[1000,5,2] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 5, 2)
#           ] ph
#           pk:f64[1000,5,7] = concatenate[dimension=2] pg pj
#           pl:f64[1000,7,7] = concatenate[dimension=1] pi pk
#         in (pl,) }
#       device=None
#       donated_invars=(False, False, False, False)
#       inline=False
#       name=vmap(block)
#     ] pb nl pa pc
#     pm:f64[1000,7,7] = transpose[permutation=(0, 2, 1)] pd
#     _:f64[1000,7,7] pn:f64[1000,7,7] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; po:f64[1000,7,7]. let
#           pp:f64[1000,7,7] pq:f64[1000,7,7] = qr[full_matrices=False] po
#         in (pp, pq) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] pm
#     pr:f64[1000,7,7] = transpose[permutation=(0, 2, 1)] pn
#     ps:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     pt:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     pu:i32[2] = concatenate[dimension=0] ps pt
#     pv:f64[1000,2,2] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(1, 2))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1000, 2, 2)
#       unique_indices=True
#     ] pr pu
#     pw:f64[1000,2,2] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(1000, 2, 2)
#     ] pv
#     px:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 2
#     py:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     pz:i32[2] = concatenate[dimension=0] px py
#     qa:f64[1000,5,2] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(1, 2))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1000, 5, 2)
#       unique_indices=True
#     ] pr pz
#     qb:f64[1000,5,2] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(1000, 5, 2)
#     ] qa
#     qc:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 2
#     qd:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 2
#     qe:i32[2] = concatenate[dimension=0] qc qd
#     qf:f64[1000,5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(1, 2))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1000, 5, 5)
#       unique_indices=True
#     ] pr qe
#     qg:f64[1000,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(1000, 5, 5)
#     ] qf
#     qh:f64[1000,2,5] = transpose[permutation=(0, 2, 1)] qb
#     qi:f64[1000,2,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; qj:f64[1000,2,2] qk:f64[1000,2,5]. let
#           ql:f64[1000,2,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=True
#             unit_diagonal=False
#           ] qj qk
#         in (ql,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(_solve_triangular)
#     ] pw qh
#     qm:f64[1000,5,2] = transpose[permutation=(0, 2, 1)] qi
#     qn:f64[1000,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] qm mk
#     qo:f64[1000,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] qn hc
#     qp:f64[1000,5,5] = sub hc qo
#     qq:f64[1000,2] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] mk os
#     qr:f64[1000,2] = convert_element_type[new_dtype=float64 weak_type=False] t
#     qs:f64[1000,2] = sub qr qq
#     qt:f64[1000,2] = sub qs oq
#     qu:f64[1000,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] qm qt
#     qv:f64[1000,5] = add os qu
#     qw:f64[1000,2,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] mk hc
#     qx:f64[1000,2,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; qy:f64[1000,2,2] qz:f64[1000,2,5]. let
#           ra:f64[1000,2,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=False
#             unit_diagonal=False
#           ] qy qz
#         in (ra,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(_solve_triangular)
#     ] pw qw
#     rb:f64[1000,5,2] = transpose[permutation=(0, 2, 1)] qx
#     rc:f64[1000,2,5] = transpose[permutation=(0, 2, 1)] rb
#     rd:f64[1000,2,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; re:f64[1000,2,2] rf:f64[1000,2,5]. let
#           rg:f64[1000,2,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=True
#             unit_diagonal=False
#           ] re rf
#         in (rg,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(_solve_triangular)
#     ] pw rc
#     rh:f64[1000,5,2] = transpose[permutation=(0, 2, 1)] rd
#     ri:f64[1000,2] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] mk ji
#     rj:f64[1000,2] = convert_element_type[new_dtype=float64 weak_type=False] t
#     rk:f64[1000,2] = sub rj ri
#     rl:f64[1000,2] = sub rk oq
#     rm:f64[1000,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] rh rl
#     rn:f64[5,3] = broadcast_in_dim[broadcast_dimensions=() shape=(5, 3)] 0.0
#     ro:f64[1000,5,3] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(1000, 5, 3)
#     ] rn
#     rp:f64[1000,5,5] = concatenate[dimension=2] rb ro
#     rq:f64[500,5,5] = slice[
#       limit_indices=(999, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] qp
#     rr:f64[500,5] = slice[
#       limit_indices=(999, 5)
#       start_indices=(0, 0)
#       strides=(2, 1)
#     ] qv
#     rs:f64[500,5,5] = slice[
#       limit_indices=(999, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] qg
#     rt:f64[500,5] = slice[
#       limit_indices=(999, 5)
#       start_indices=(0, 0)
#       strides=(2, 1)
#     ] rm
#     ru:f64[500,5,5] = slice[
#       limit_indices=(999, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] rp
#     rv:f64[500,5,5] = slice[
#       limit_indices=(1000, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] qp
#     rw:f64[500,5] = slice[
#       limit_indices=(1000, 5)
#       start_indices=(1, 0)
#       strides=(2, 1)
#     ] qv
#     rx:f64[500,5,5] = slice[
#       limit_indices=(1000, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] qg
#     ry:f64[500,5] = slice[
#       limit_indices=(1000, 5)
#       start_indices=(1, 0)
#       strides=(2, 1)
#     ] rm
#     rz:f64[500,5,5] = slice[
#       limit_indices=(1000, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] rp
#     sa:f64[500,5,5] = transpose[permutation=(0, 2, 1)] rs
#     sb:f64[500,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] sa rz
#     sc:i32[5,5] = iota[dimension=0 dtype=int32 shape=(5, 5)]
#     sd:i32[5,5] = add sc 0
#     se:i32[5,5] = iota[dimension=1 dtype=int32 shape=(5, 5)]
#     sf:bool[5,5] = eq sd se
#     sg:f64[5,5] = convert_element_type[new_dtype=float64 weak_type=False] sf
#     sh:f64[5,5] = broadcast_in_dim[broadcast_dimensions=() shape=(5, 5)] 0.0
#     si:f64[500,10,10] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; sj:f64[500,5,5] sk:f64[5,5] sl:f64[500,5,5] sm:f64[5,5]. let
#           sn:f64[500,5,5] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(500, 5, 5)
#           ] sk
#           so:f64[500,5,10] = concatenate[dimension=2] sj sn
#           sp:f64[500,5,5] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(500, 5, 5)
#           ] sm
#           sq:f64[500,5,10] = concatenate[dimension=2] sl sp
#           sr:f64[500,10,10] = concatenate[dimension=1] so sq
#         in (sr,) }
#       device=None
#       donated_invars=(False, False, False, False)
#       inline=False
#       name=vmap(block)
#     ] sb sg rz sh
#     ss:f64[500,10,10] = transpose[permutation=(0, 2, 1)] si
#     _:f64[500,10,10] st:f64[500,10,10] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; su:f64[500,10,10]. let
#           sv:f64[500,10,10] sw:f64[500,10,10] = qr[full_matrices=False] su
#         in (sv, sw) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] ss
#     sx:f64[500,10,10] = transpose[permutation=(0, 2, 1)] st
#     sy:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     sz:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     ta:i32[2] = concatenate[dimension=0] sy sz
#     tb:f64[500,5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(1, 2))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(500, 5, 5)
#       unique_indices=True
#     ] sx ta
#     tc:f64[500,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(500, 5, 5)
#     ] tb
#     td:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 5
#     te:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     tf:i32[2] = concatenate[dimension=0] td te
#     tg:f64[500,5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(1, 2))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(500, 5, 5)
#       unique_indices=True
#     ] sx tf
#     th:f64[500,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(500, 5, 5)
#     ] tg
#     ti:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 5
#     tj:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 5
#     tk:i32[2] = concatenate[dimension=0] ti tj
#     tl:f64[500,5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(1, 2))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(500, 5, 5)
#       unique_indices=True
#     ] sx tk
#     tm:f64[500,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(500, 5, 5)
#     ] tl
#     tn:f64[500,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] rv rq
#     to:f64[500,5,5] = transpose[permutation=(0, 2, 1)] rs
#     tp:f64[500,5,5] = transpose[permutation=(0, 2, 1)] rv
#     tq:f64[500,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] to tp
#     tr:f64[500,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; ts:f64[500,5,5] tt:f64[500,5,5]. let
#           tu:f64[500,5,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=False
#             unit_diagonal=False
#           ] ts tt
#         in (tu,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(_solve_triangular)
#     ] tc tq
#     tv:f64[500,5,5] = transpose[permutation=(0, 2, 1)] tr
#     tw:f64[500,5,5] = transpose[permutation=(0, 2, 1)] th
#     tx:f64[500,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] tv tw
#     ty:f64[500,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] tx rq
#     tz:f64[500,5,5] = sub tn ty
#     ua:i32[5,5] = iota[dimension=0 dtype=int32 shape=(5, 5)]
#     ub:i32[5,5] = add ua 0
#     uc:i32[5,5] = iota[dimension=1 dtype=int32 shape=(5, 5)]
#     ud:bool[5,5] = eq ub uc
#     ue:f64[5,5] = convert_element_type[new_dtype=float64 weak_type=False] ud
#     uf:f64[500,5,5] = transpose[permutation=(0, 2, 1)] rs
#     ug:f64[500,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; uh:f64[500,5,5] ui:f64[500,5,5]. let
#           uj:f64[500,5,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=False
#             unit_diagonal=False
#           ] uh ui
#         in (uj,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(_solve_triangular)
#     ] tc uf
#     uk:f64[500,5,5] = transpose[permutation=(0, 2, 1)] ug
#     ul:f64[500,5,5] = transpose[permutation=(0, 2, 1)] th
#     um:f64[500,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] uk ul
#     un:f64[500,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(500, 5, 5)
#     ] ue
#     uo:f64[500,5,5] = sub un um
#     up:f64[500,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
# ...
#     eff:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] vk
#     efg:f64[250,5,5] = concatenate[dimension=0] eff edu
#     efh:f64[1,5] = slice[
#       limit_indices=(1, 5)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] wh
#     efi:f64[250,5] = concatenate[dimension=0] efh eer
#     efj:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] wq
#     efk:f64[250,5,5] = concatenate[dimension=0] efj efa
#     efl:f64[500,5,5] = pad[padding_config=((0, 1, 1), (0, 0, 0), (0, 0, 0))] efc
#       0.0
#     efm:f64[500,5,5] = pad[padding_config=((1, 0, 1), (0, 0, 0), (0, 0, 0))] dzn
#       0.0
#     efn:f64[500,5,5] = add efl efm
#     efo:f64[500,5] = pad[padding_config=((0, 1, 1), (0, 0, 0))] efe 0.0
#     efp:f64[500,5] = pad[padding_config=((1, 0, 1), (0, 0, 0))] dzq 0.0
#     efq:f64[500,5] = add efo efp
#     efr:f64[500,5,5] = pad[padding_config=((0, 1, 1), (0, 0, 0), (0, 0, 0))] efg
#       0.0
#     efs:f64[500,5,5] = pad[padding_config=((1, 0, 1), (0, 0, 0), (0, 0, 0))] dzt
#       0.0
#     eft:f64[500,5,5] = add efr efs
#     efu:f64[500,5] = pad[padding_config=((0, 1, 1), (0, 0, 0))] efi 0.0
#     efv:f64[500,5] = pad[padding_config=((1, 0, 1), (0, 0, 0))] dzw 0.0
#     efw:f64[500,5] = add efu efv
#     efx:f64[500,5,5] = pad[padding_config=((0, 1, 1), (0, 0, 0), (0, 0, 0))] efk
#       0.0
#     efy:f64[500,5,5] = pad[padding_config=((1, 0, 1), (0, 0, 0), (0, 0, 0))] dzz
#       0.0
#     efz:f64[500,5,5] = add efx efy
#     ega:f64[499,5,5] = slice[
#       limit_indices=(499, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] efn
#     egb:f64[499,5] = slice[
#       limit_indices=(499, 5)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] efq
#     egc:f64[499,5,5] = slice[
#       limit_indices=(499, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] eft
#     egd:f64[499,5] = slice[
#       limit_indices=(499, 5)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] efw
#     ege:f64[499,5,5] = slice[
#       limit_indices=(499, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] efz
#     egf:f64[499,5,5] = slice[
#       limit_indices=(1000, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] qp
#     egg:f64[499,5] = slice[
#       limit_indices=(1000, 5)
#       start_indices=(2, 0)
#       strides=(2, 1)
#     ] qv
#     egh:f64[499,5,5] = slice[
#       limit_indices=(1000, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] qg
#     egi:f64[499,5] = slice[
#       limit_indices=(1000, 5)
#       start_indices=(2, 0)
#       strides=(2, 1)
#     ] rm
#     egj:f64[499,5,5] = slice[
#       limit_indices=(1000, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] rp
#     egk:f64[499,5,5] = transpose[permutation=(0, 2, 1)] egc
#     egl:f64[499,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] egk egj
#     egm:i32[5,5] = iota[dimension=0 dtype=int32 shape=(5, 5)]
#     egn:i32[5,5] = add egm 0
#     ego:i32[5,5] = iota[dimension=1 dtype=int32 shape=(5, 5)]
#     egp:bool[5,5] = eq egn ego
#     egq:f64[5,5] = convert_element_type[new_dtype=float64 weak_type=False] egp
#     egr:f64[5,5] = broadcast_in_dim[broadcast_dimensions=() shape=(5, 5)] 0.0
#     egs:f64[499,10,10] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; egt:f64[499,5,5] egu:f64[5,5] egv:f64[499,5,5] egw:f64[5,5]. let
#           egx:f64[499,5,5] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(499, 5, 5)
#           ] egu
#           egy:f64[499,5,10] = concatenate[dimension=2] egt egx
#           egz:f64[499,5,5] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(499, 5, 5)
#           ] egw
#           eha:f64[499,5,10] = concatenate[dimension=2] egv egz
#           ehb:f64[499,10,10] = concatenate[dimension=1] egy eha
#         in (ehb,) }
#       device=None
#       donated_invars=(False, False, False, False)
#       inline=False
#       name=vmap(block)
#     ] egl egq egj egr
#     ehc:f64[499,10,10] = transpose[permutation=(0, 2, 1)] egs
#     _:f64[499,10,10] ehd:f64[499,10,10] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; ehe:f64[499,10,10]. let
#           ehf:f64[499,10,10] ehg:f64[499,10,10] = qr[full_matrices=False] ehe
#         in (ehf, ehg) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] ehc
#     ehh:f64[499,10,10] = transpose[permutation=(0, 2, 1)] ehd
#     ehi:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     ehj:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     ehk:i32[2] = concatenate[dimension=0] ehi ehj
#     ehl:f64[499,5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(1, 2))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(499, 5, 5)
#       unique_indices=True
#     ] ehh ehk
#     ehm:f64[499,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(499, 5, 5)
#     ] ehl
#     ehn:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 5
#     eho:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     ehp:i32[2] = concatenate[dimension=0] ehn eho
#     ehq:f64[499,5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(1, 2))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(499, 5, 5)
#       unique_indices=True
#     ] ehh ehp
#     ehr:f64[499,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(499, 5, 5)
#     ] ehq
#     ehs:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 5
#     eht:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 5
#     ehu:i32[2] = concatenate[dimension=0] ehs eht
#     ehv:f64[499,5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(1, 2))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(499, 5, 5)
#       unique_indices=True
#     ] ehh ehu
#     ehw:f64[499,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(499, 5, 5)
#     ] ehv
#     ehx:f64[499,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] egf ega
#     ehy:f64[499,5,5] = transpose[permutation=(0, 2, 1)] egc
#     ehz:f64[499,5,5] = transpose[permutation=(0, 2, 1)] egf
#     eia:f64[499,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ehy ehz
#     eib:f64[499,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; eic:f64[499,5,5] eid:f64[499,5,5]. let
#           eie:f64[499,5,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=False
#             unit_diagonal=False
#           ] eic eid
#         in (eie,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(_solve_triangular)
#     ] ehm eia
#     eif:f64[499,5,5] = transpose[permutation=(0, 2, 1)] eib
#     eig:f64[499,5,5] = transpose[permutation=(0, 2, 1)] ehr
#     eih:f64[499,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] eif eig
#     eii:f64[499,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] eih ega
#     eij:f64[499,5,5] = sub ehx eii
#     eik:i32[5,5] = iota[dimension=0 dtype=int32 shape=(5, 5)]
#     eil:i32[5,5] = add eik 0
#     eim:i32[5,5] = iota[dimension=1 dtype=int32 shape=(5, 5)]
#     ein:bool[5,5] = eq eil eim
#     eio:f64[5,5] = convert_element_type[new_dtype=float64 weak_type=False] ein
#     eip:f64[499,5,5] = transpose[permutation=(0, 2, 1)] egc
#     eiq:f64[499,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; eir:f64[499,5,5] eis:f64[499,5,5]. let
#           eit:f64[499,5,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=False
#             unit_diagonal=False
#           ] eir eis
#         in (eit,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(_solve_triangular)
#     ] ehm eip
#     eiu:f64[499,5,5] = transpose[permutation=(0, 2, 1)] eiq
#     eiv:f64[499,5,5] = transpose[permutation=(0, 2, 1)] ehr
#     eiw:f64[499,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] eiu eiv
#     eix:f64[499,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(499, 5, 5)
#     ] eio
#     eiy:f64[499,5,5] = sub eix eiw
#     eiz:f64[499,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] egf eiy
#     eja:f64[499,5,5] = transpose[permutation=(0, 2, 1)] egc
#     ejb:f64[499,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] egc eja
#     ejc:f64[499,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ejb egi
#     ejd:f64[499,5] = add egb ejc
#     eje:f64[499,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] eiz ejd
#     ejf:f64[499,5] = add eje egg
#     ejg:f64[499,5,5] = transpose[permutation=(0, 2, 1)] egc
#     ejh:f64[499,5,5] = transpose[permutation=(0, 2, 1)] egf
#     eji:f64[499,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ejg ejh
#     ejj:f64[499,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; ejk:f64[499,5,5] ejl:f64[499,5,5]. let
#           ejm:f64[499,5,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=False
#             unit_diagonal=False
#           ] ejk ejl
#         in (ejm,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(_solve_triangular)
#     ] ehm eji
#     ejn:f64[499,5,5] = transpose[permutation=(0, 2, 1)] ejj
#     ejo:f64[499,5,10] = concatenate[dimension=2] ejn egh
#     ejp:f64[499,10,5] = transpose[permutation=(0, 2, 1)] ejo
#     _:f64[499,10,5] ejq:f64[499,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; ejr:f64[499,10,5]. let
#           ejs:f64[499,10,5] ejt:f64[499,5,5] = qr[full_matrices=False] ejr
#         in (ejs, ejt) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] ejp
#     eju:f64[499,5,5] = transpose[permutation=(0, 2, 1)] ejq
#     ejv:f64[499,5,5] = transpose[permutation=(0, 2, 1)] ega
#     ejw:i32[5,5] = iota[dimension=0 dtype=int32 shape=(5, 5)]
#     ejx:i32[5,5] = add ejw 0
#     ejy:i32[5,5] = iota[dimension=1 dtype=int32 shape=(5, 5)]
#     ejz:bool[5,5] = eq ejx ejy
#     eka:f64[5,5] = convert_element_type[new_dtype=float64 weak_type=False] ejz
#     ekb:f64[499,5,5] = transpose[permutation=(0, 2, 1)] ehr
#     ekc:f64[499,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; ekd:f64[499,5,5] eke:f64[499,5,5]. let
#           ekf:f64[499,5,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=True
#             unit_diagonal=False
#           ] ekd eke
#         in (ekf,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(_solve_triangular)
#     ] ehm ekb
#     ekg:f64[499,5,5] = transpose[permutation=(0, 2, 1)] ekc
#     ekh:f64[499,5,5] = transpose[permutation=(0, 2, 1)] egc
#     eki:f64[499,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ekg ekh
#     ekj:f64[499,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(499, 5, 5)
#     ] eka
#     ekk:f64[499,5,5] = sub ekj eki
#     ekl:f64[499,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ejv ekk
#     ekm:f64[499,5,5] = transpose[permutation=(0, 2, 1)] egj
#     ekn:f64[499,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] egj ekm
#     eko:f64[499,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ekn egb
#     ekp:f64[499,5] = sub egi eko
#     ekq:f64[499,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ekl ekp
#     ekr:f64[499,5] = add ekq egd
#     eks:f64[499,5,5] = transpose[permutation=(0, 2, 1)] ega
#     ekt:f64[499,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] eks ehw
#     eku:f64[499,5,10] = concatenate[dimension=2] ekt ege
#     ekv:f64[499,10,5] = transpose[permutation=(0, 2, 1)] eku
#     _:f64[499,10,5] ekw:f64[499,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; ekx:f64[499,10,5]. let
#           eky:f64[499,10,5] ekz:f64[499,5,5] = qr[full_matrices=False] ekx
#         in (eky, ekz) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] ekv
#     ela:f64[499,5,5] = transpose[permutation=(0, 2, 1)] ekw
#     elb:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] qp
#     elc:f64[500,5,5] = concatenate[dimension=0] elb eij
#     eld:f64[1,5] = slice[
#       limit_indices=(1, 5)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] qv
#     ele:f64[500,5] = concatenate[dimension=0] eld ejf
#     elf:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] qg
#     elg:f64[500,5,5] = concatenate[dimension=0] elf eju
#     elh:f64[1,5] = slice[
#       limit_indices=(1, 5)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] rm
#     eli:f64[500,5] = concatenate[dimension=0] elh ekr
#     elj:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] rp
#     elk:f64[500,5,5] = concatenate[dimension=0] elj ela
#     ell:f64[1000,5,5] = pad[padding_config=((0, 1, 1), (0, 0, 0), (0, 0, 0))] elc
#       0.0
#     elm:f64[1000,5,5] = pad[padding_config=((1, 0, 1), (0, 0, 0), (0, 0, 0))] efn
#       0.0
#     _:f64[1000,5,5] = add ell elm
#     eln:f64[1000,5] = pad[padding_config=((0, 1, 1), (0, 0, 0))] ele 0.0
#     elo:f64[1000,5] = pad[padding_config=((1, 0, 1), (0, 0, 0))] efq 0.0
#     elp:f64[1000,5] = add eln elo
#     elq:f64[1000,5,5] = pad[padding_config=((0, 1, 1), (0, 0, 0), (0, 0, 0))] elg
#       0.0
#     elr:f64[1000,5,5] = pad[padding_config=((1, 0, 1), (0, 0, 0), (0, 0, 0))] eft
#       0.0
#     els:f64[1000,5,5] = add elq elr
#     elt:f64[1000,5] = pad[padding_config=((0, 1, 1), (0, 0, 0))] eli 0.0
#     elu:f64[1000,5] = pad[padding_config=((1, 0, 1), (0, 0, 0))] efw 0.0
#     _:f64[1000,5] = add elt elu
#     elv:f64[1000,5,5] = pad[padding_config=((0, 1, 1), (0, 0, 0), (0, 0, 0))] elk
#       0.0
#     elw:f64[1000,5,5] = pad[padding_config=((1, 0, 1), (0, 0, 0), (0, 0, 0))] efz
#       0.0
#     _:f64[1000,5,5] = add elv elw
#     elx:f64[1,5] = broadcast_in_dim[broadcast_dimensions=(1,) shape=(1, 5)] c
#     ely:f64[1001,5] = concatenate[dimension=0] elx elp
#     elz:f64[1,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(1, 5, 5)
#     ] d
#     ema:f64[1001,5,5] = concatenate[dimension=0] elz els
#   in (ely, ema) }

# %%
smoothing(sqrt_transition_model, filtering_res, cubature, initial_states_sqrt, True
# Out:
# MVNSqrt(mean=DeviceArray([[ 1.79996472, -1.20435104, -1.72239084,  0.02290087,
#                2.43380679],
#              [ 1.7828263 , -1.20408521, -1.70545753,  0.03008791,
#                2.4329721 ],
#              [ 1.76585766, -1.2037489 , -1.68843612,  0.0369935 ,
#                2.43188142],
#              ...,
#              [ 0.54121006, -0.38268165, -0.18081399,  0.21488959,
#                1.98437165],
#              [ 0.53941946, -0.38051074, -0.17739055,  0.2192186 ,
#                1.98437163],
#              [ 0.53766352, -0.37829688, -0.17388116,  0.22347832,
#                1.98437163]], dtype=float64), chol=DeviceArray([[[ 0.30273472,  0.        ,  0.        ,  0.        ,
#                 0.        ],
#               [-0.07276094,  0.13456888,  0.        ,  0.        ,
#                 0.        ],
#               [-0.48459588,  0.32215358, -0.31872375,  0.        ,
#                 0.        ],
#               [-0.08400899, -0.21904561,  0.22144642,  0.22193481,
#                 0.        ],
#               [ 0.07149683, -0.06133732,  0.12864866,  0.08949022,
#                -0.12796194]],
#
#              [[-0.29792805,  0.        ,  0.        ,  0.        ,
#                 0.        ],
#               [ 0.07217268, -0.1331705 ,  0.        ,  0.        ,
#                 0.        ],
#               [ 0.47676695, -0.31716802,  0.31767168,  0.        ,
#                 0.        ],
#               [ 0.08330787,  0.2148832 , -0.21980714, -0.22166697,
#                 0.        ],
#               [-0.06958278,  0.05931775, -0.12742849, -0.08915604,
#                 0.12795757]],
#
#              [[-0.29319926,  0.        ,  0.        ,  0.        ,
#                 0.        ],
#               [ 0.07159152, -0.13180773,  0.        ,  0.        ,
#                 0.        ],
#               [ 0.46901823, -0.31228795,  0.31661752,  0.        ,
#                 0.        ],
#               [ 0.08261595,  0.21074866, -0.21815184, -0.22138715,
#                 0.        ],
#               [-0.0676976 ,  0.05731201, -0.126189  , -0.0888    ,
#                 0.12794236]],
#
#              ...,
#
#              [[-0.15202586,  0.        ,  0.        ,  0.        ,
#                 0.        ],
#               [ 0.10128206, -0.22442708,  0.        ,  0.        ,
#                 0.        ],
#               [-0.06151397, -0.141911  ,  0.22963611,  0.        ,
#                 0.        ],
#               [ 0.47982356, -0.5231299 , -0.3664182 , -0.29950753,
#                 0.        ],
#               [-0.09458718,  0.10585649,  0.16995049,  0.05995462,
#                 0.13538087]],
#
#              [[ 0.15263564,  0.        ,  0.        ,  0.        ,
#                 0.        ],
#               [-0.10397105,  0.2307042 ,  0.        ,  0.        ,
#                 0.        ],
#               [ 0.06041718,  0.14558203, -0.22963999,  0.        ,
#                 0.        ],
#               [-0.48731792,  0.53866099,  0.36643161,  0.29950667,
#                 0.        ],
#               [ 0.09613555, -0.10912664, -0.16995511, -0.05995548,
#                -0.1353808 ]],
#
#              [[-0.15323428,  0.        ,  0.        ,  0.        ,
#                 0.        ],
#               [ 0.10662421, -0.23718432,  0.        ,  0.        ,
#                 0.        ],
#               [-0.05928594, -0.1495259 ,  0.22964076,  0.        ,
#                 0.        ],
#               [ 0.49459756, -0.55423206, -0.36643269, -0.29950181,
#                 0.        ],
#               [-0.09761985,  0.11234235,  0.16995585,  0.05995546,
#                 0.13538072]]], dtype=float64))

# %%
spec_smoothing = lambda : smoothing(sqrt_transition_model, filtering_res, cubature, initial_states_sqrt, True)
smoothing_jaxpr = jax.make_jaxpr(spec_smoothing)()

# %%
smoothing_jaxpr
# Out:
# { lambda a:f64[1001,5] b:f64[1001,5,5] c:f64[1001,5] d:f64[1001,5,5] e:f64[5,10]
#     f:i64[5] g:f64[10] h:f64[1,10] i:f64[10,1] j:f64[5,5] k:f64[5]; . let
#     l:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     m:f64[1000,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1), collapsed_slice_dims=(), start_index_map=(0,))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1000, 5)
#       unique_indices=True
#     ] a l
#     n:f64[1000,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1)
#       shape=(1000, 5)
#     ] m
#     o:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     p:f64[1000,5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(0,))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1000, 5, 5)
#       unique_indices=True
#     ] b o
#     q:f64[1000,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(1000, 5, 5)
#     ] p
#     r:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     s:f64[1000,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1), collapsed_slice_dims=(), start_index_map=(0,))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1000, 5)
#       unique_indices=True
#     ] c r
#     t:f64[1000,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1)
#       shape=(1000, 5)
#     ] s
#     u:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     v:f64[1000,5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(0,))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1000, 5, 5)
#       unique_indices=True
#     ] d u
#     w:f64[1000,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(1000, 5, 5)
#     ] v
#     x:f64[1000,1,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 2)
#       shape=(1000, 1, 5)
#     ] n
#     y:f64[1000,5,10] = dot_general[
#       dimension_numbers=(((2,), (0,)), ((), ()))
#       precision=None
#       preferred_element_type=None
#     ] q e
#     z:f64[1000,10,5] = transpose[permutation=(0, 2, 1)] y
#     ba:f64[1000,10,5] = add x z
#     bb:f64[1000,10,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; bc:i64[5] bd:f64[1000,10,5]. let
#           be:bool[] = lt -1 0
#           bf:i64[] = add -1 5
#           bg:i64[] = select be bf -1
#           bh:i32[] = convert_element_type[new_dtype=int32 weak_type=False] bg
#           bi:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] bh
#           bj:f64[1000,10] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1), collapsed_slice_dims=(2,), start_index_map=(2,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1000, 10, 1)
#             unique_indices=True
#           ] bd bi
#           bk:f64[1000,10] = abs bj
#           bl:bool[1000,10] = lt bk 1e-06
#           bm:f64[1000,10] = mul bj 0.01
#           bn:f64[1000,10] = cos bm
#           bo:f64[1000,10] = mul bj 0.01
#           bp:f64[1000,10] = sin bo
#           bq:i32[1000,10] = convert_element_type[
#             new_dtype=int32
#             weak_type=False
#           ] bl
#           br:bool[1000,10] = eq bq 0
#           bs:f64[1000,10] = stop_gradient bn
#           _:f64[1000,10] = select br bn bs
#           bt:bool[1000,10] = eq bq 0
#           bu:f64[1000,10] = stop_gradient bp
#           _:f64[1000,10] = select bt bp bu
#           bv:bool[1000,10] = eq bq 0
#           bw:f64[1000,10] = stop_gradient bn
#           bx:f64[1000,10] = select bv bn bw
#           by:bool[1000,10] = eq bq 0
#           bz:f64[1000,10] = stop_gradient bj
#           ca:f64[1000,10] = select by bj bz
#           cb:bool[1000,10] = eq bq 0
#           cc:f64[1000,10] = stop_gradient bp
#           cd:f64[1000,10] = select cb bp cc
#           ce:f64[1000,10] = sub bx 1.0
#           cf:f64[1000,10] = div ce ca
#           cg:f64[1000,10] = div cd ca
#           ch:bool[1000,10] = eq bq 1
#           ci:f64[1000,10] = stop_gradient bn
#           cj:f64[1000,10] = select ch bn ci
#           ck:bool[1000,10] = eq bq 1
#           cl:f64[1000,10] = stop_gradient bp
#           cm:f64[1000,10] = select ck bp cl
#           cn:bool[1000,10] = eq bq 1
#           co:f64[1000,10] = stop_gradient bn
#           _:f64[1000,10] = select cn bn co
#           cp:bool[1000,10] = eq bq 1
#           cq:f64[1000,10] = stop_gradient bj
#           _:f64[1000,10] = select cp bj cq
#           cr:bool[1000,10] = eq bq 1
#           cs:f64[1000,10] = stop_gradient bp
#           _:f64[1000,10] = select cr bp cs
#           ct:f64[10] = broadcast_in_dim[broadcast_dimensions=() shape=(10,)] 0.0
#           cu:f64[10] = broadcast_in_dim[broadcast_dimensions=() shape=(10,)] 0.01
#           cv:bool[1000,10] = lt bq 1
#           _:i32[1000,10] = sub bq 1
#           cw:f64[1000,10] = select cv bx cj
#           cx:bool[1000,10] = lt bq 1
#           _:i32[1000,10] = sub bq 1
#           cy:f64[1000,10] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(1000, 10)
#           ] ct
#           cz:f64[1000,10] = select cx cf cy
#           da:bool[1000,10] = lt bq 1
#           _:i32[1000,10] = sub bq 1
#           db:f64[1000,10] = select da cd cm
#           dc:bool[1000,10] = lt bq 1
#           _:i32[1000,10] = sub bq 1
#           dd:f64[1000,10] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(1000, 10)
#           ] cu
#           de:f64[1000,10] = select dc cg dd
#           df:f64[1000,10] = neg cz
#           dg:f64[1000,10] = neg db
#           dh:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 1
#           di:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           dj:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] de
#           dk:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] df
#           dl:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           dm:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] dh
#           dn:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] di
#           do:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] dl
#           dp:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] dm
#           dq:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] dn
#           dr:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] do
#           ds:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] dp
#           dt:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] dq
#           du:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] dr
#           dv:f64[1000,10,5] = concatenate[dimension=2] ds dt dj dk du
#           dw:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           dx:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 1
#           dy:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] cz
#           dz:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] de
#           ea:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           eb:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] dw
#           ec:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] dx
#           ed:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] ea
#           ee:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] eb
#           ef:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] ec
#           eg:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] ed
#           eh:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] ee
#           ei:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] ef
#           ej:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] eg
#           ek:f64[1000,10,5] = concatenate[dimension=2] eh ei dy dz ej
#           el:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           em:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           en:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] cw
#           eo:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] db
#           ep:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           eq:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] el
#           er:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] em
#           es:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] ep
#           et:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] eq
#           eu:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] er
#           ev:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] es
#           ew:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] et
#           ex:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] eu
#           ey:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] ev
#           ez:f64[1000,10,5] = concatenate[dimension=2] ew ex en eo ey
#           fa:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           fb:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           fc:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] dg
#           fd:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 10, 1)
#           ] cw
#           fe:i64[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           ff:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] fa
#           fg:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] fb
#           fh:f64[1] = convert_element_type[new_dtype=float64 weak_type=False] fe
#           fi:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] ff
#           fj:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] fg
#           fk:f64[10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(10, 1)
#           ] fh
#           fl:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] fi
#           fm:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] fj
#           fn:f64[1000,10,1] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 10, 1)
#           ] fk
#           fo:f64[1000,10,5] = concatenate[dimension=2] fl fm fc fd fn
#           fp:f64[1000,10,1,5] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 3)
#             shape=(1000, 10, 1, 5)
#           ] dv
#           fq:f64[1000,10,1,5] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 3)
#             shape=(1000, 10, 1, 5)
#           ] ek
#           fr:f64[1000,10,1,5] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 3)
#             shape=(1000, 10, 1, 5)
#           ] ez
#           fs:f64[1000,10,1,5] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 3)
#             shape=(1000, 10, 1, 5)
#           ] fo
#           ft:i64[1,5] = broadcast_in_dim[broadcast_dimensions=(1,) shape=(1, 5)] bc
#           fu:f64[1,5] = convert_element_type[new_dtype=float64 weak_type=False] ft
#           fv:f64[10,1,5] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(10, 1, 5)
#           ] fu
#           fw:f64[1000,10,1,5] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2, 3)
#             shape=(1000, 10, 1, 5)
#           ] fv
#           fx:f64[1000,10,5,5] = concatenate[dimension=2] fp fq fr fs fw
#           fy:f64[1000,10,5] = dot_general[
#             dimension_numbers=(((3,), (2,)), ((0, 1), (0, 1)))
#             precision=None
#             preferred_element_type=None
#           ] fx bd
#         in (fy,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(vmap(<unnamed wrapped function>))
#     ] f ba
#     fz:f64[1000,5] = dot_general[
#       dimension_numbers=(((0,), (1,)), ((), ()))
#       precision=None
#       preferred_element_type=None
#     ] g bb
#     ga:f64[1000,1,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 2)
#       shape=(1000, 1, 5)
#     ] n
#     gb:f64[1000,10,5] = sub ba ga
#     gc:f64[1000,5,10] = transpose[permutation=(0, 2, 1)] gb
#     gd:f64[1000,1,10] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(1000, 1, 10)
#     ] h
#     ge:f64[1000,5,10] = mul gc gd
#     gf:f64[1000,1,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 2)
#       shape=(1000, 1, 5)
#     ] fz
#     gg:f64[1000,10,5] = sub bb gf
#     gh:f64[1000,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ge gg
#     gi:f64[1000,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; gj:f64[1000,5,5] gk:f64[1000,5,5]. let
#           gl:f64[1000,5,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=False
#             unit_diagonal=False
#           ] gj gk
#           gm:f64[1000,5,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=True
#             unit_diagonal=False
#           ] gj gl
#         in (gm,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(_cho_solve)
#     ] q gh
#     gn:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] gi
#     go:f64[10,1] = sqrt i
#     gp:f64[1000,1,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 2)
#       shape=(1000, 1, 5)
#     ] fz
#     gq:f64[1000,10,5] = sub bb gp
#     gr:f64[1000,10,1] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(1000, 10, 1)
#     ] go
#     gs:f64[1000,10,5] = mul gr gq
#     gt:f64[1000,5,10] = transpose[permutation=(0, 2, 1)] gs
#     gu:f64[1000,10,5] = transpose[permutation=(0, 2, 1)] gt
#     _:f64[1000,10,5] gv:f64[1000,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; gw:f64[1000,10,5]. let
#           gx:f64[1000,10,5] gy:f64[1000,5,5] = qr[full_matrices=False] gw
#         in (gx, gy) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] gu
#     gz:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] gv
#     ha:f64[1000,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(1000, 5, 5)
#     ] j
#     hb:f64[1000,5,10] = concatenate[dimension=2] gz ha
#     hc:f64[1000,10,5] = transpose[permutation=(0, 2, 1)] hb
#     _:f64[1000,10,5] hd:f64[1000,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; he:f64[1000,10,5]. let
#           hf:f64[1000,10,5] hg:f64[1000,5,5] = qr[full_matrices=False] he
#         in (hf, hg) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] hc
#     hh:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] hd
#     hi:f64[1000,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] gn q
#     hj:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] hh
#     hk:f64[1000,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] hh hj
#     hl:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] hi
#     hm:f64[1000,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] hi hl
#     hn:f64[1000,5,5] = sub hk hm
#     ho:f64[1000,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; hp:f64[1000,5,5]. let
#           hq:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] hp
#           hr:f64[1000,5,5] = add hp hq
#           hs:f64[1000,5,5] = div hr 2.0
#           ht:f64[1000,5,5] = cholesky hs
#           hu:f64[1000,5,5] = xla_call[
#             backend=None
#             call_jaxpr={ lambda ; hv:f64[1000,5,5]. let
#                 hw:i32[5,5] = iota[dimension=0 dtype=int32 shape=(5, 5)]
#                 hx:i32[5,5] = add hw 0
#                 hy:i32[5,5] = iota[dimension=1 dtype=int32 shape=(5, 5)]
#                 hz:bool[5,5] = ge hx hy
#                 ia:bool[5,5] = convert_element_type[
#                   new_dtype=bool
#                   weak_type=False
#                 ] hz
#                 ib:bool[1000,5,5] = broadcast_in_dim[
#                   broadcast_dimensions=(1, 2)
#                   shape=(1000, 5, 5)
#                 ] ia
#                 ic:f64[1000,5,5] = broadcast_in_dim[
#                   broadcast_dimensions=()
#                   shape=(1000, 5, 5)
#                 ] 0.0
#                 id:f64[1000,5,5] = select ib hv ic
#               in (id,) }
#             device=None
#             donated_invars=(False,)
#             inline=False
#             name=tril
#           ] ht
#           ie:f64[1000,5,5] = xla_call[
#             backend=None
#             call_jaxpr={ lambda ; if:f64[1000,5,5]. let
#                 ig:i32[5,5] = iota[dimension=0 dtype=int32 shape=(5, 5)]
#                 ih:i32[5,5] = add ig 0
#                 ii:i32[5,5] = iota[dimension=1 dtype=int32 shape=(5, 5)]
#                 ij:bool[5,5] = ge ih ii
#                 ik:bool[5,5] = convert_element_type[
#                   new_dtype=bool
#                   weak_type=False
#                 ] ij
#                 il:bool[5,5] = broadcast_in_dim[
#                   broadcast_dimensions=(0, 1)
#                   shape=(5, 5)
#                 ] ik
#                 im:f64[5,5] = broadcast_in_dim[
#                   broadcast_dimensions=()
#                   shape=(5, 5)
#                 ] 0.0
#                 in:bool[1000,5,5] = broadcast_in_dim[
#                   broadcast_dimensions=(1, 2)
#                   shape=(1000, 5, 5)
#                 ] il
#                 io:f64[1000,5,5] = broadcast_in_dim[
#                   broadcast_dimensions=(1, 2)
#                   shape=(1000, 5, 5)
#                 ] im
#                 ip:f64[1000,5,5] = select in if io
#               in (ip,) }
#             device=None
#             donated_invars=(False,)
#             inline=False
#             name=vmap(tril)
#           ] hu
#         in (ie,) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_cholesky)
#     ] hn
#     iq:f64[1000,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] gn n
#     ir:f64[1000,5] = sub fz iq
#     is:f64[1000,5] = broadcast_in_dim[broadcast_dimensions=(1,) shape=(1000, 5)] k
#     it:f64[1000,5] = add ir is
#     iu:f64[1000,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] gn w
#     iv:f64[5,5] = broadcast_in_dim[broadcast_dimensions=() shape=(5, 5)] 0.0
#     iw:f64[1000,10,10] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; ix:f64[1000,5,5] iy:f64[1000,5,5] iz:f64[1000,5,5] ja:f64[5,5]. let
#           jb:f64[1000,5,10] = concatenate[dimension=2] ix iy
#           jc:f64[1000,5,5] = broadcast_in_dim[
#             broadcast_dimensions=(1, 2)
#             shape=(1000, 5, 5)
#           ] ja
#           jd:f64[1000,5,10] = concatenate[dimension=2] iz jc
#           je:f64[1000,10,10] = concatenate[dimension=1] jb jd
#         in (je,) }
#       device=None
#       donated_invars=(False, False, False, False)
#       inline=False
#       name=vmap(block)
#     ] iu ho w iv
#     jf:f64[1000,10,10] = transpose[permutation=(0, 2, 1)] iw
#     _:f64[1000,10,10] jg:f64[1000,10,10] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; jh:f64[1000,10,10]. let
#           ji:f64[1000,10,10] jj:f64[1000,10,10] = qr[full_matrices=False] jh
#         in (ji, jj) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] jf
#     jk:f64[1000,10,10] = transpose[permutation=(0, 2, 1)] jg
#     jl:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     jm:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     jn:i32[2] = concatenate[dimension=0] jl jm
#     jo:f64[1000,5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(1, 2))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1000, 5, 5)
#       unique_indices=True
#     ] jk jn
#     jp:f64[1000,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(1000, 5, 5)
#     ] jo
#     jq:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 5
#     jr:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#     js:i32[2] = concatenate[dimension=0] jq jr
#     jt:f64[1000,5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(1, 2))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1000, 5, 5)
#       unique_indices=True
#     ] jk js
#     ju:f64[1000,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(1000, 5, 5)
#     ] jt
#     jv:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 5
#     jw:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 5
#     jx:i32[2] = concatenate[dimension=0] jv jw
#     jy:f64[1000,5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(1, 2))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1000, 5, 5)
#       unique_indices=True
#     ] jk jx
#     jz:f64[1000,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(0, 1, 2)
#       shape=(1000, 5, 5)
#     ] jy
#     ka:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] jp
#     kb:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] ju
#     kc:f64[1000,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; kd:f64[1000,5,5] ke:f64[1000,5,5]. let
#           kf:f64[1000,5,5] = xla_call[
#             backend=None
#             call_jaxpr={ lambda ; kg:f64[1000,5,5] kh:f64[1000,5,5]. let
#                 ki:f64[1000,5,5] = stop_gradient kg
#                 kj:f64[1000,5,5] _:i32[1000,5] kk:i32[1000,5] = lu ki
#                 kl:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] kh
#                 km:f64[1000,5,5] = custom_linear_solve[
#                   const_lengths=_LinearSolveTuple(matvec=1, vecmat=1, solve=2, transpose_solve=2)
#                   jaxprs=_LinearSolveTuple(matvec={ lambda ; a:f64[1000,5,5] b:f64[1000,5,5]. let
#     c:f64[1000,5,5] = dot_general[
#       dimension_numbers=(((2,), (2,)), ((0,), (0,)))
#       precision=(<PrecisionConfig_Precision.HIGHEST: 2>, <PrecisionConfig_Precision.HIGHEST: 2>)
#       preferred_element_type=None
#     ] a b
#     d:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] c
#   in (d,) }, vecmat={ lambda ; a:f64[1000,5,5] b:f64[1000,5,5]. let
#     c:f64[1000,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=(<PrecisionConfig_Precision.HIGHEST: 2>, <PrecisionConfig_Precision.HIGHEST: 2>)
#       preferred_element_type=None
#     ] b a
#   in (c,) }, solve={ lambda ; a:f64[1000,5,5] b:i32[1000,5] c:f64[1000,5,5]. let
#     d:f64[1000,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; e:f64[1000,5,5] f:i32[1000,5] g:f64[1000,5,5]. let
#           h:f64[1000,5,5,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 2)
#             shape=(1000, 5, 5, 1)
#           ] g
#           i:bool[1000,5] = lt f 0
#           j:i32[1000,5] = add f 5
#           k:i32[1000,5] = select i j f
#           l:i32[1000,5,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 5, 1)
#           ] k
#           m:i32[1000,5,1] = iota[dimension=0 dtype=int32 shape=(1000, 5, 1)]
#           n:i32[1000,5,2] = concatenate[dimension=2] m l
#           o:f64[1000,5,5,1] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(1, 3), collapsed_slice_dims=(0, 2), start_index_map=(0, 2))
#             fill_value=None
#             indices_are_sorted=False
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1, 5, 1, 1)
#             unique_indices=False
#           ] h n
#           p:f64[1000,5,5,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 2, 3)
#             shape=(1000, 5, 5, 1)
#           ] o
#           q:f64[1000,5,1,5] = transpose[permutation=(0, 2, 3, 1)] p
#           r:f64[1000,5,5] = reshape[dimensions=None new_sizes=(1000, 5, 5)] q
#           s:f64[1000,5,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=False
#             unit_diagonal=True
#           ] e r
#           t:f64[1000,5,1,5] = reshape[dimensions=None new_sizes=(1000, 5, 1, 5)] s
#           u:f64[1000,5,5] = reshape[dimensions=None new_sizes=(1000, 5, 5)] t
#           v:f64[1000,5,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=False
#             transpose_a=False
#             unit_diagonal=False
#           ] e u
#           w:f64[1000,5,1,5] = reshape[dimensions=None new_sizes=(1000, 5, 1, 5)] v
#           x:bool[] = lt 0 0
#           y:i64[] = add 0 1
#           z:i64[] = select x y 0
#           ba:i32[] = convert_element_type[new_dtype=int32 weak_type=False] z
#           bb:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] ba
#           bc:f64[1000,5,5,1] = transpose[permutation=(0, 3, 1, 2)] w
#           bd:f64[1000,5,5] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(3,), start_index_map=(3,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1000, 5, 5, 1)
#             unique_indices=True
#           ] bc bb
#           be:f64[1000,5,5] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 2)
#             shape=(1000, 5, 5)
#           ] bd
#         in (be,) }
#       device=None
#       donated_invars=(False, False, False)
#       inline=False
#       name=vmap(vmap(_lu_solve))
#     ] a b c
#   in (d,) }, transpose_solve={ lambda ; a:f64[1000,5,5] b:i32[1000,5] c:f64[1000,5,5]. let
#     d:f64[1000,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; e:f64[1000,5,5] f:i32[1000,5] g:f64[1000,5,5]. let
#           h:f64[1000,5,5,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 2)
#             shape=(1000, 5, 5, 1)
#           ] g
#           i:f64[1000,5,1,5] = transpose[permutation=(0, 2, 3, 1)] h
#           j:f64[1000,5,5] = reshape[dimensions=None new_sizes=(1000, 5, 5)] i
#           k:f64[1000,5,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=False
#             transpose_a=True
#             unit_diagonal=False
#           ] e j
#           l:f64[1000,5,1,5] = reshape[dimensions=None new_sizes=(1000, 5, 1, 5)] k
#           m:f64[1000,5,5] = reshape[dimensions=None new_sizes=(1000, 5, 5)] l
#           n:f64[1000,5,5] = triangular_solve[
#             conjugate_a=False
#             left_side=True
#             lower=True
#             transpose_a=True
#             unit_diagonal=True
#           ] e m
#           o:f64[1000,5,1,5] = reshape[dimensions=None new_sizes=(1000, 5, 1, 5)] n
#           p:i64[1000,5] = xla_call[
#             backend=None
#             call_jaxpr={ lambda ; q:i32[1000,5]. let
#                 r:i64[5] = iota[dimension=0 dtype=int64 shape=(5,)]
#                 s:i64[1000,5] = broadcast_in_dim[
#                   broadcast_dimensions=(1,)
#                   shape=(1000, 5)
#                 ] r
#                 _:i32[1000,5] t:i64[1000,5] = sort[
#                   dimension=1
#                   is_stable=True
#                   num_keys=1
#                 ] q s
#               in (t,) }
#             device=None
#             donated_invars=(False,)
#             inline=False
#             name=vmap(argsort)
#           ] f
#           u:bool[1000,5] = lt p 0
#           v:i64[1000,5] = add p 5
#           w:i64[1000,5] = select u v p
#           x:i32[1000,5] = convert_element_type[new_dtype=int32 weak_type=False] w
#           y:i32[1000,5,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(1000, 5, 1)
#           ] x
#           z:f64[1000,5,5,1] = transpose[permutation=(0, 3, 1, 2)] o
#           ba:i32[1000,5,1] = iota[dimension=0 dtype=int32 shape=(1000, 5, 1)]
#           bb:i32[1000,5,2] = concatenate[dimension=2] ba y
#           bc:f64[1000,5,5,1] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(1, 3), collapsed_slice_dims=(0, 2), start_index_map=(0, 2))
#             fill_value=None
#             indices_are_sorted=False
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1, 5, 1, 1)
#             unique_indices=False
#           ] z bb
#           bd:f64[1000,5,5,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 2, 3)
#             shape=(1000, 5, 5, 1)
#           ] bc
#           be:bool[] = lt 0 0
#           bf:i64[] = add 0 1
#           bg:i64[] = select be bf 0
#           bh:i32[] = convert_element_type[new_dtype=int32 weak_type=False] bg
#           bi:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] bh
#           bj:f64[1000,5,5] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(3,), start_index_map=(3,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(1000, 5, 5, 1)
#             unique_indices=True
#           ] bd bi
#           bk:f64[1000,5,5] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1, 2)
#             shape=(1000, 5, 5)
#           ] bj
#         in (bk,) }
#       device=None
#       donated_invars=(False, False, False)
#       inline=False
#       name=vmap(vmap(_lu_solve))
#     ] a b c
#   in (d,) })
#                 ] kg kg kj kk kj kk kl
#                 kn:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] km
#               in (kn,) }
#             device=None
#             donated_invars=(False, False)
#             inline=False
#             name=vmap(solve)
#           ] kd ke
#         in (kf,) }
#       device=None
#       donated_invars=(False, False)
#       inline=False
#       name=vmap(_solve)
#     ] ka kb
#     ko:f64[1000,5,5] = transpose[permutation=(0, 2, 1)] kc
#     kp:f64[1000,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] gn t
#     kq:f64[1000,5] = add kp it
#     kr:f64[1000,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ko kq
#     ks:f64[1000,5] = sub t kr
#     kt:bool[] = lt -1 0
#     ku:i64[] = add -1 1001
#     kv:i64[] = select kt ku -1
#     kw:i32[] = convert_element_type[new_dtype=int32 weak_type=False] kv
#     kx:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] kw
#     ky:f64[5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0,), collapsed_slice_dims=(0,), start_index_map=(0,))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 5)
#       unique_indices=True
#     ] c kx
#     kz:f64[5] = broadcast_in_dim[broadcast_dimensions=(0,) shape=(5,)] ky
#     la:bool[] = lt -1 0
#     lb:i64[] = add -1 1001
#     lc:i64[] = select la lb -1
#     ld:i32[] = convert_element_type[new_dtype=int32 weak_type=False] lc
#     le:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] ld
#     lf:f64[5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1), collapsed_slice_dims=(0,), start_index_map=(0,))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 5, 5)
#       unique_indices=True
#     ] d le
#     _:f64[5,5] = broadcast_in_dim[broadcast_dimensions=(0, 1) shape=(5, 5)] lf
#     lg:f64[5,5] = broadcast_in_dim[broadcast_dimensions=() shape=(5, 5)] 0.0
#     lh:bool[] = lt -1 0
#     li:i64[] = add -1 1001
#     lj:i64[] = select lh li -1
#     lk:i32[] = convert_element_type[new_dtype=int32 weak_type=False] lj
#     ll:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] lk
#     lm:f64[5,5] = gather[
#       dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1), collapsed_slice_dims=(0,), start_index_map=(0,))
#       fill_value=None
#       indices_are_sorted=True
#       mode=GatherScatterMode.PROMISE_IN_BOUNDS
#       slice_sizes=(1, 5, 5)
#       unique_indices=True
#     ] d ll
#     ln:f64[5,5] = broadcast_in_dim[broadcast_dimensions=(0, 1) shape=(5, 5)] lm
#     lo:f64[1,5] = broadcast_in_dim[broadcast_dimensions=(1,) shape=(1, 5)] kz
#     lp:f64[1001,5] = concatenate[dimension=0] ks lo
#     lq:f64[1,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(1, 5, 5)
#     ] lg
#     lr:f64[1001,5,5] = concatenate[dimension=0] ko lq
#     ls:f64[1,5,5] = broadcast_in_dim[
#       broadcast_dimensions=(1, 2)
#       shape=(1, 5, 5)
#     ] ln
#     lt:f64[1001,5,5] = concatenate[dimension=0] jz ls
#     lu:f64[1001,5] = rev[dimensions=(0,)] lp
#     lv:f64[1001,5,5] = rev[dimensions=(0,)] lr
#     lw:f64[1001,5,5] = rev[dimensions=(0,)] lt
#     lx:f64[500,5] = slice[
#       limit_indices=(1000, 5)
#       start_indices=(0, 0)
#       strides=(2, 1)
#     ] lu
#     ly:f64[500,5,5] = slice[
#       limit_indices=(1000, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] lv
#     lz:f64[500,5,5] = slice[
#       limit_indices=(1000, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] lw
#     ma:f64[500,5] = slice[
#       limit_indices=(1001, 5)
#       start_indices=(1, 0)
#       strides=(2, 1)
#     ] lu
#     mb:f64[500,5,5] = slice[
#       limit_indices=(1001, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] lv
#     mc:f64[500,5,5] = slice[
#       limit_indices=(1001, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] lw
#     md:f64[500,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] mb lx
#     me:f64[500,5] = add md ma
#     mf:f64[500,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] mb ly
#     mg:f64[500,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] mb lz
#     mh:f64[500,5,10] = concatenate[dimension=2] mg mc
#     mi:f64[500,10,5] = transpose[permutation=(0, 2, 1)] mh
#     _:f64[500,10,5] mj:f64[500,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; mk:f64[500,10,5]. let
#           ml:f64[500,10,5] mm:f64[500,5,5] = qr[full_matrices=False] mk
#         in (ml, mm) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] mi
#     mn:f64[500,5,5] = transpose[permutation=(0, 2, 1)] mj
#     mo:f64[250,5] = slice[
#       limit_indices=(499, 5)
#       start_indices=(0, 0)
#       strides=(2, 1)
#     ] me
#     mp:f64[250,5,5] = slice[
#       limit_indices=(499, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] mf
#     mq:f64[250,5,5] = slice[
#       limit_indices=(499, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] mn
#     mr:f64[250,5] = slice[
#       limit_indices=(500, 5)
#       start_indices=(1, 0)
#       strides=(2, 1)
#     ] me
#     ms:f64[250,5,5] = slice[
#       limit_indices=(500, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] mf
#     mt:f64[250,5,5] = slice[
#       limit_indices=(500, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] mn
#     mu:f64[250,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ms mo
#     mv:f64[250,5] = add mu mr
#     mw:f64[250,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ms mp
#     mx:f64[250,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ms mq
#     my:f64[250,5,10] = concatenate[dimension=2] mx mt
#     mz:f64[250,10,5] = transpose[permutation=(0, 2, 1)] my
#     _:f64[250,10,5] na:f64[250,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; nb:f64[250,10,5]. let
#           nc:f64[250,10,5] nd:f64[250,5,5] = qr[full_matrices=False] nb
#         in (nc, nd) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] mz
#     ne:f64[250,5,5] = transpose[permutation=(0, 2, 1)] na
#     nf:f64[125,5] = slice[
#       limit_indices=(249, 5)
#       start_indices=(0, 0)
#       strides=(2, 1)
#     ] mv
#     ng:f64[125,5,5] = slice[
#       limit_indices=(249, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] mw
#     nh:f64[125,5,5] = slice[
#       limit_indices=(249, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] ne
#     ni:f64[125,5] = slice[
#       limit_indices=(250, 5)
#       start_indices=(1, 0)
#       strides=(2, 1)
#     ] mv
#     nj:f64[125,5,5] = slice[
#       limit_indices=(250, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] mw
#     nk:f64[125,5,5] = slice[
#       limit_indices=(250, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] ne
#     nl:f64[125,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] nj nf
#     nm:f64[125,5] = add nl ni
#     nn:f64[125,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] nj ng
#     no:f64[125,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] nj nh
#     np:f64[125,5,10] = concatenate[dimension=2] no nk
#     nq:f64[125,10,5] = transpose[permutation=(0, 2, 1)] np
#     _:f64[125,10,5] nr:f64[125,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; ns:f64[125,10,5]. let
#           nt:f64[125,10,5] nu:f64[125,5,5] = qr[full_matrices=False] ns
#         in (nt, nu) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] nq
#     nv:f64[125,5,5] = transpose[permutation=(0, 2, 1)] nr
#     nw:f64[62,5] = slice[
#       limit_indices=(124, 5)
#       start_indices=(0, 0)
#       strides=(2, 1)
#     ] nm
#     nx:f64[62,5,5] = slice[
#       limit_indices=(124, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] nn
#     ny:f64[62,5,5] = slice[
#       limit_indices=(124, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] nv
#     nz:f64[62,5] = slice[
#       limit_indices=(125, 5)
#       start_indices=(1, 0)
#       strides=(2, 1)
#     ] nm
#     oa:f64[62,5,5] = slice[
#       limit_indices=(125, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] nn
#     ob:f64[62,5,5] = slice[
#       limit_indices=(125, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] nv
#     oc:f64[62,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] oa nw
#     od:f64[62,5] = add oc nz
#     oe:f64[62,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] oa nx
#     of:f64[62,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] oa ny
#     og:f64[62,5,10] = concatenate[dimension=2] of ob
#     oh:f64[62,10,5] = transpose[permutation=(0, 2, 1)] og
#     _:f64[62,10,5] oi:f64[62,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; oj:f64[62,10,5]. let
#           ok:f64[62,10,5] ol:f64[62,5,5] = qr[full_matrices=False] oj
#         in (ok, ol) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] oh
#     om:f64[62,5,5] = transpose[permutation=(0, 2, 1)] oi
#     on:f64[31,5] = slice[
#       limit_indices=(61, 5)
#       start_indices=(0, 0)
#       strides=(2, 1)
#     ] od
#     oo:f64[31,5,5] = slice[
#       limit_indices=(61, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] oe
#     op:f64[31,5,5] = slice[
#       limit_indices=(61, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] om
#     oq:f64[31,5] = slice[
#       limit_indices=(62, 5)
#       start_indices=(1, 0)
#       strides=(2, 1)
#     ] od
#     or:f64[31,5,5] = slice[
#       limit_indices=(62, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] oe
#     os:f64[31,5,5] = slice[
#       limit_indices=(62, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] om
#     ot:f64[31,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] or on
#     ou:f64[31,5] = add ot oq
#     ov:f64[31,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] or oo
#     ow:f64[31,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] or op
#     ox:f64[31,5,10] = concatenate[dimension=2] ow os
#     oy:f64[31,10,5] = transpose[permutation=(0, 2, 1)] ox
#     _:f64[31,10,5] oz:f64[31,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; pa:f64[31,10,5]. let
#           pb:f64[31,10,5] pc:f64[31,5,5] = qr[full_matrices=False] pa
#         in (pb, pc) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] oy
#     pd:f64[31,5,5] = transpose[permutation=(0, 2, 1)] oz
#     pe:f64[15,5] = slice[
#       limit_indices=(30, 5)
#       start_indices=(0, 0)
#       strides=(2, 1)
#     ] ou
#     pf:f64[15,5,5] = slice[
#       limit_indices=(30, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] ov
#     pg:f64[15,5,5] = slice[
#       limit_indices=(30, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] pd
#     ph:f64[15,5] = slice[
#       limit_indices=(31, 5)
#       start_indices=(1, 0)
#       strides=(2, 1)
#     ] ou
#     pi:f64[15,5,5] = slice[
#       limit_indices=(31, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] ov
#     pj:f64[15,5,5] = slice[
#       limit_indices=(31, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] pd
#     pk:f64[15,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] pi pe
#     pl:f64[15,5] = add pk ph
#     pm:f64[15,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] pi pf
#     pn:f64[15,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] pi pg
#     po:f64[15,5,10] = concatenate[dimension=2] pn pj
#     pp:f64[15,10,5] = transpose[permutation=(0, 2, 1)] po
#     _:f64[15,10,5] pq:f64[15,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; pr:f64[15,10,5]. let
#           ps:f64[15,10,5] pt:f64[15,5,5] = qr[full_matrices=False] pr
#         in (ps, pt) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] pp
#     pu:f64[15,5,5] = transpose[permutation=(0, 2, 1)] pq
#     pv:f64[7,5] = slice[
#       limit_indices=(14, 5)
#       start_indices=(0, 0)
#       strides=(2, 1)
#     ] pl
#     pw:f64[7,5,5] = slice[
#       limit_indices=(14, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] pm
#     px:f64[7,5,5] = slice[
#       limit_indices=(14, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] pu
#     py:f64[7,5] = slice[
#       limit_indices=(15, 5)
#       start_indices=(1, 0)
#       strides=(2, 1)
#     ] pl
#     pz:f64[7,5,5] = slice[
#       limit_indices=(15, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] pm
#     qa:f64[7,5,5] = slice[
#       limit_indices=(15, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] pu
#     qb:f64[7,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] pz pv
#     qc:f64[7,5] = add qb py
#     qd:f64[7,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] pz pw
#     qe:f64[7,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] pz px
#     qf:f64[7,5,10] = concatenate[dimension=2] qe qa
#     qg:f64[7,10,5] = transpose[permutation=(0, 2, 1)] qf
#     _:f64[7,10,5] qh:f64[7,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; qi:f64[7,10,5]. let
#           qj:f64[7,10,5] qk:f64[7,5,5] = qr[full_matrices=False] qi
#         in (qj, qk) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] qg
#     ql:f64[7,5,5] = transpose[permutation=(0, 2, 1)] qh
#     qm:f64[3,5] = slice[
#       limit_indices=(6, 5)
#       start_indices=(0, 0)
#       strides=(2, 1)
#     ] qc
#     qn:f64[3,5,5] = slice[
#       limit_indices=(6, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] qd
#     qo:f64[3,5,5] = slice[
#       limit_indices=(6, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(2, 1, 1)
#     ] ql
#     qp:f64[3,5] = slice[
#       limit_indices=(7, 5)
#       start_indices=(1, 0)
#       strides=(2, 1)
#     ] qc
#     qq:f64[3,5,5] = slice[
#       limit_indices=(7, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] qd
#     qr:f64[3,5,5] = slice[
#       limit_indices=(7, 5, 5)
#       start_indices=(1, 0, 0)
#       strides=(2, 1, 1)
#     ] ql
#     qs:f64[3,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] qq qm
#     qt:f64[3,5] = add qs qp
#     qu:f64[3,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] qq qn
#     qv:f64[3,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] qq qo
#     qw:f64[3,5,10] = concatenate[dimension=2] qv qr
#     qx:f64[3,10,5] = transpose[permutation=(0, 2, 1)] qw
#     _:f64[3,10,5] qy:f64[3,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; qz:f64[3,10,5]. let
#           ra:f64[3,10,5] rb:f64[3,5,5] = qr[full_matrices=False] qz
# ...
#     uz:f64[15,5,5] = add ux uy
#     va:f64[15,5,5] = pad[padding_config=((0, 0, 1), (0, 0, 0), (0, 0, 0))] ut 0.0
#     vb:f64[15,5,5] = pad[padding_config=((1, 1, 1), (0, 0, 0), (0, 0, 0))] tz 0.0
#     vc:f64[15,5,5] = add va vb
#     vd:f64[15,5] = slice[
#       limit_indices=(31, 5)
#       start_indices=(2, 0)
#       strides=(2, 1)
#     ] ou
#     ve:f64[15,5,5] = slice[
#       limit_indices=(31, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] ov
#     vf:f64[15,5,5] = slice[
#       limit_indices=(31, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] pd
#     vg:f64[15,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ve uw
#     vh:f64[15,5] = add vg vd
#     vi:f64[15,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ve uz
#     vj:f64[15,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] ve vc
#     vk:f64[15,5,10] = concatenate[dimension=2] vj vf
#     vl:f64[15,10,5] = transpose[permutation=(0, 2, 1)] vk
#     _:f64[15,10,5] vm:f64[15,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; vn:f64[15,10,5]. let
#           vo:f64[15,10,5] vp:f64[15,5,5] = qr[full_matrices=False] vn
#         in (vo, vp) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] vl
#     vq:f64[15,5,5] = transpose[permutation=(0, 2, 1)] vm
#     vr:f64[1,5] = slice[
#       limit_indices=(1, 5)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] ou
#     vs:f64[16,5] = concatenate[dimension=0] vr vh
#     vt:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] ov
#     vu:f64[16,5,5] = concatenate[dimension=0] vt vi
#     vv:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] pd
#     vw:f64[16,5,5] = concatenate[dimension=0] vv vq
#     vx:f64[31,5] = pad[padding_config=((0, 0, 1), (0, 0, 0))] vs 0.0
#     vy:f64[31,5] = pad[padding_config=((1, 1, 1), (0, 0, 0))] uw 0.0
#     vz:f64[31,5] = add vx vy
#     wa:f64[31,5,5] = pad[padding_config=((0, 0, 1), (0, 0, 0), (0, 0, 0))] vu 0.0
#     wb:f64[31,5,5] = pad[padding_config=((1, 1, 1), (0, 0, 0), (0, 0, 0))] uz 0.0
#     wc:f64[31,5,5] = add wa wb
#     wd:f64[31,5,5] = pad[padding_config=((0, 0, 1), (0, 0, 0), (0, 0, 0))] vw 0.0
#     we:f64[31,5,5] = pad[padding_config=((1, 1, 1), (0, 0, 0), (0, 0, 0))] vc 0.0
#     wf:f64[31,5,5] = add wd we
#     wg:f64[30,5] = slice[
#       limit_indices=(30, 5)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] vz
#     wh:f64[30,5,5] = slice[
#       limit_indices=(30, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] wc
#     wi:f64[30,5,5] = slice[
#       limit_indices=(30, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] wf
#     wj:f64[30,5] = slice[
#       limit_indices=(62, 5)
#       start_indices=(2, 0)
#       strides=(2, 1)
#     ] od
#     wk:f64[30,5,5] = slice[
#       limit_indices=(62, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] oe
#     wl:f64[30,5,5] = slice[
#       limit_indices=(62, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] om
#     wm:f64[30,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] wk wg
#     wn:f64[30,5] = add wm wj
#     wo:f64[30,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] wk wh
#     wp:f64[30,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] wk wi
#     wq:f64[30,5,10] = concatenate[dimension=2] wp wl
#     wr:f64[30,10,5] = transpose[permutation=(0, 2, 1)] wq
#     _:f64[30,10,5] ws:f64[30,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; wt:f64[30,10,5]. let
#           wu:f64[30,10,5] wv:f64[30,5,5] = qr[full_matrices=False] wt
#         in (wu, wv) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] wr
#     ww:f64[30,5,5] = transpose[permutation=(0, 2, 1)] ws
#     wx:f64[1,5] = slice[
#       limit_indices=(1, 5)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] od
#     wy:f64[31,5] = concatenate[dimension=0] wx wn
#     wz:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] oe
#     xa:f64[31,5,5] = concatenate[dimension=0] wz wo
#     xb:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] om
#     xc:f64[31,5,5] = concatenate[dimension=0] xb ww
#     xd:f64[62,5] = pad[padding_config=((0, 1, 1), (0, 0, 0))] wy 0.0
#     xe:f64[62,5] = pad[padding_config=((1, 0, 1), (0, 0, 0))] vz 0.0
#     xf:f64[62,5] = add xd xe
#     xg:f64[62,5,5] = pad[padding_config=((0, 1, 1), (0, 0, 0), (0, 0, 0))] xa 0.0
#     xh:f64[62,5,5] = pad[padding_config=((1, 0, 1), (0, 0, 0), (0, 0, 0))] wc 0.0
#     xi:f64[62,5,5] = add xg xh
#     xj:f64[62,5,5] = pad[padding_config=((0, 1, 1), (0, 0, 0), (0, 0, 0))] xc 0.0
#     xk:f64[62,5,5] = pad[padding_config=((1, 0, 1), (0, 0, 0), (0, 0, 0))] wf 0.0
#     xl:f64[62,5,5] = add xj xk
#     xm:f64[62,5] = slice[
#       limit_indices=(125, 5)
#       start_indices=(2, 0)
#       strides=(2, 1)
#     ] nm
#     xn:f64[62,5,5] = slice[
#       limit_indices=(125, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] nn
#     xo:f64[62,5,5] = slice[
#       limit_indices=(125, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] nv
#     xp:f64[62,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] xn xf
#     xq:f64[62,5] = add xp xm
#     xr:f64[62,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] xn xi
#     xs:f64[62,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] xn xl
#     xt:f64[62,5,10] = concatenate[dimension=2] xs xo
#     xu:f64[62,10,5] = transpose[permutation=(0, 2, 1)] xt
#     _:f64[62,10,5] xv:f64[62,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; xw:f64[62,10,5]. let
#           xx:f64[62,10,5] xy:f64[62,5,5] = qr[full_matrices=False] xw
#         in (xx, xy) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] xu
#     xz:f64[62,5,5] = transpose[permutation=(0, 2, 1)] xv
#     ya:f64[1,5] = slice[
#       limit_indices=(1, 5)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] nm
#     yb:f64[63,5] = concatenate[dimension=0] ya xq
#     yc:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] nn
#     yd:f64[63,5,5] = concatenate[dimension=0] yc xr
#     ye:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] nv
#     yf:f64[63,5,5] = concatenate[dimension=0] ye xz
#     yg:f64[125,5] = pad[padding_config=((0, 0, 1), (0, 0, 0))] yb 0.0
#     yh:f64[125,5] = pad[padding_config=((1, 1, 1), (0, 0, 0))] xf 0.0
#     yi:f64[125,5] = add yg yh
#     yj:f64[125,5,5] = pad[padding_config=((0, 0, 1), (0, 0, 0), (0, 0, 0))] yd 0.0
#     yk:f64[125,5,5] = pad[padding_config=((1, 1, 1), (0, 0, 0), (0, 0, 0))] xi 0.0
#     yl:f64[125,5,5] = add yj yk
#     ym:f64[125,5,5] = pad[padding_config=((0, 0, 1), (0, 0, 0), (0, 0, 0))] yf 0.0
#     yn:f64[125,5,5] = pad[padding_config=((1, 1, 1), (0, 0, 0), (0, 0, 0))] xl 0.0
#     yo:f64[125,5,5] = add ym yn
#     yp:f64[124,5] = slice[
#       limit_indices=(124, 5)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] yi
#     yq:f64[124,5,5] = slice[
#       limit_indices=(124, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] yl
#     yr:f64[124,5,5] = slice[
#       limit_indices=(124, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] yo
#     ys:f64[124,5] = slice[
#       limit_indices=(250, 5)
#       start_indices=(2, 0)
#       strides=(2, 1)
#     ] mv
#     yt:f64[124,5,5] = slice[
#       limit_indices=(250, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] mw
#     yu:f64[124,5,5] = slice[
#       limit_indices=(250, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] ne
#     yv:f64[124,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] yt yp
#     yw:f64[124,5] = add yv ys
#     yx:f64[124,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] yt yq
#     yy:f64[124,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] yt yr
#     yz:f64[124,5,10] = concatenate[dimension=2] yy yu
#     za:f64[124,10,5] = transpose[permutation=(0, 2, 1)] yz
#     _:f64[124,10,5] zb:f64[124,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; zc:f64[124,10,5]. let
#           zd:f64[124,10,5] ze:f64[124,5,5] = qr[full_matrices=False] zc
#         in (zd, ze) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] za
#     zf:f64[124,5,5] = transpose[permutation=(0, 2, 1)] zb
#     zg:f64[1,5] = slice[
#       limit_indices=(1, 5)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] mv
#     zh:f64[125,5] = concatenate[dimension=0] zg yw
#     zi:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] mw
#     zj:f64[125,5,5] = concatenate[dimension=0] zi yx
#     zk:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] ne
#     zl:f64[125,5,5] = concatenate[dimension=0] zk zf
#     zm:f64[250,5] = pad[padding_config=((0, 1, 1), (0, 0, 0))] zh 0.0
#     zn:f64[250,5] = pad[padding_config=((1, 0, 1), (0, 0, 0))] yi 0.0
#     zo:f64[250,5] = add zm zn
#     zp:f64[250,5,5] = pad[padding_config=((0, 1, 1), (0, 0, 0), (0, 0, 0))] zj 0.0
#     zq:f64[250,5,5] = pad[padding_config=((1, 0, 1), (0, 0, 0), (0, 0, 0))] yl 0.0
#     zr:f64[250,5,5] = add zp zq
#     zs:f64[250,5,5] = pad[padding_config=((0, 1, 1), (0, 0, 0), (0, 0, 0))] zl 0.0
#     zt:f64[250,5,5] = pad[padding_config=((1, 0, 1), (0, 0, 0), (0, 0, 0))] yo 0.0
#     zu:f64[250,5,5] = add zs zt
#     zv:f64[249,5] = slice[
#       limit_indices=(249, 5)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] zo
#     zw:f64[249,5,5] = slice[
#       limit_indices=(249, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] zr
#     zx:f64[249,5,5] = slice[
#       limit_indices=(249, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] zu
#     zy:f64[249,5] = slice[
#       limit_indices=(500, 5)
#       start_indices=(2, 0)
#       strides=(2, 1)
#     ] me
#     zz:f64[249,5,5] = slice[
#       limit_indices=(500, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] mf
#     baa:f64[249,5,5] = slice[
#       limit_indices=(500, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] mn
#     bab:f64[249,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] zz zv
#     bac:f64[249,5] = add bab zy
#     bad:f64[249,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] zz zw
#     bae:f64[249,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] zz zx
#     baf:f64[249,5,10] = concatenate[dimension=2] bae baa
#     bag:f64[249,10,5] = transpose[permutation=(0, 2, 1)] baf
#     _:f64[249,10,5] bah:f64[249,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; bai:f64[249,10,5]. let
#           baj:f64[249,10,5] bak:f64[249,5,5] = qr[full_matrices=False] bai
#         in (baj, bak) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] bag
#     bal:f64[249,5,5] = transpose[permutation=(0, 2, 1)] bah
#     bam:f64[1,5] = slice[
#       limit_indices=(1, 5)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] me
#     ban:f64[250,5] = concatenate[dimension=0] bam bac
#     bao:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] mf
#     bap:f64[250,5,5] = concatenate[dimension=0] bao bad
#     baq:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] mn
#     bar:f64[250,5,5] = concatenate[dimension=0] baq bal
#     bas:f64[500,5] = pad[padding_config=((0, 1, 1), (0, 0, 0))] ban 0.0
#     bat:f64[500,5] = pad[padding_config=((1, 0, 1), (0, 0, 0))] zo 0.0
#     bau:f64[500,5] = add bas bat
#     bav:f64[500,5,5] = pad[padding_config=((0, 1, 1), (0, 0, 0), (0, 0, 0))] bap
#       0.0
#     baw:f64[500,5,5] = pad[padding_config=((1, 0, 1), (0, 0, 0), (0, 0, 0))] zr 0.0
#     bax:f64[500,5,5] = add bav baw
#     bay:f64[500,5,5] = pad[padding_config=((0, 1, 1), (0, 0, 0), (0, 0, 0))] bar
#       0.0
#     baz:f64[500,5,5] = pad[padding_config=((1, 0, 1), (0, 0, 0), (0, 0, 0))] zu 0.0
#     bba:f64[500,5,5] = add bay baz
#     bbb:f64[500,5] = slice[
#       limit_indices=(1001, 5)
#       start_indices=(2, 0)
#       strides=(2, 1)
#     ] lu
#     bbc:f64[500,5,5] = slice[
#       limit_indices=(1001, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] lv
#     bbd:f64[500,5,5] = slice[
#       limit_indices=(1001, 5, 5)
#       start_indices=(2, 0, 0)
#       strides=(2, 1, 1)
#     ] lw
#     bbe:f64[500,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] bbc bau
#     bbf:f64[500,5] = add bbe bbb
#     bbg:f64[500,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] bbc bax
#     bbh:f64[500,5,5] = dot_general[
#       dimension_numbers=(((2,), (1,)), ((0,), (0,)))
#       precision=None
#       preferred_element_type=None
#     ] bbc bba
#     bbi:f64[500,5,10] = concatenate[dimension=2] bbh bbd
#     bbj:f64[500,10,5] = transpose[permutation=(0, 2, 1)] bbi
#     _:f64[500,10,5] bbk:f64[500,5,5] = xla_call[
#       backend=None
#       call_jaxpr={ lambda ; bbl:f64[500,10,5]. let
#           bbm:f64[500,10,5] bbn:f64[500,5,5] = qr[full_matrices=False] bbl
#         in (bbm, bbn) }
#       device=None
#       donated_invars=(False,)
#       inline=False
#       name=vmap(_qr)
#     ] bbj
#     bbo:f64[500,5,5] = transpose[permutation=(0, 2, 1)] bbk
#     bbp:f64[1,5] = slice[
#       limit_indices=(1, 5)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] lu
#     bbq:f64[501,5] = concatenate[dimension=0] bbp bbf
#     bbr:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] lv
#     bbs:f64[501,5,5] = concatenate[dimension=0] bbr bbg
#     bbt:f64[1,5,5] = slice[
#       limit_indices=(1, 5, 5)
#       start_indices=(0, 0, 0)
#       strides=(1, 1, 1)
#     ] lw
#     bbu:f64[501,5,5] = concatenate[dimension=0] bbt bbo
#     bbv:f64[1001,5] = pad[padding_config=((0, 0, 1), (0, 0, 0))] bbq 0.0
#     bbw:f64[1001,5] = pad[padding_config=((1, 1, 1), (0, 0, 0))] bau 0.0
#     bbx:f64[1001,5] = add bbv bbw
#     bby:f64[1001,5,5] = pad[padding_config=((0, 0, 1), (0, 0, 0), (0, 0, 0))] bbs
#       0.0
#     bbz:f64[1001,5,5] = pad[padding_config=((1, 1, 1), (0, 0, 0), (0, 0, 0))] bax
#       0.0
#     bca:f64[1001,5,5] = add bby bbz
#     bcb:f64[1001,5,5] = pad[padding_config=((0, 0, 1), (0, 0, 0), (0, 0, 0))] bbu
#       0.0
#     bcc:f64[1001,5,5] = pad[padding_config=((1, 1, 1), (0, 0, 0), (0, 0, 0))] bba
#       0.0
#     bcd:f64[1001,5,5] = add bcb bcc
#     bce:f64[1001,5] = rev[dimensions=(0,)] bbx
#     _:f64[1001,5,5] = rev[dimensions=(0,)] bca
#     bcf:f64[1001,5,5] = rev[dimensions=(0,)] bcd
#   in (bce, bcf) }
